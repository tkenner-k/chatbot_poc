# %% [markdown]
# ### Import Dependencies

# %%
from pydantic import BaseModel

from langchain_openai import ChatOpenAI

from langsmith import traceable

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode


from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from IPython.display import Image, display

from typing import Any, Annotated, List
from pydantic import Field
from operator import add

from jinja2 import Template

from utils.tools import get_formatted_item_context, get_formatted_reviews_context, get_shopping_cart, remove_from_cart, add_to_shopping_cart, check_warehouse_availability, reserve_warehouse_items

# %% [markdown]
# ### Worker Agents

# %% [markdown]
# Product QnA Agent

# %%
class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question")
    description: str = Field(description="Description of the item used to answer the question")

class FinalQnAAgentResponse(BaseModel):

    """Call this tool when the final answer is possible using available context."""

    answer: str = Field(description="Answer to the question")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question")

# %%
@traceable(
    name="product_qna_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def product_qna_agent(state) -> dict:
    
    prompt_template = """You are a shopping assistant answering customer questions about products in stock.

## Procedure

Before every tool call, check what previous tool calls in this conversation already
returned. Search only for what's genuinely missing. If nothing is missing, call
FinalResponse instead — previously retrieved data is as valid as fresh data, and
re-running a search you already ran is an error.

Customer: "Which of those speakers is cheapest?"
→ Speakers and prices already retrieved. No search. FinalResponse.

Customer: "Does that jacket come with a rain shell, and do you have gloves?"
→ Jacket specs already retrieved; gloves are not. Search gloves only.

## Answering

- Never state a product detail that isn't in the retrieved data.
- Describe products with specifications in bullet points.
- In references, include every chunk that contributed to your answer with the chunk id and product name.
- Call retrieved data "available products", never "context".
- Nothing relevant returned → say so, ask the customer to refine.
- Off-topic question → ask what product they're interested in.
"""

    template = Template(prompt_template)

    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [get_formatted_item_context, get_formatted_reviews_context, FinalQnAAgentResponse],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *state.messages
        ]
    )

    final_answer = False
    answer = ""
    references = []

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalQnAAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalQnAAgentResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")
                references.extend(tool_call.get("args").get("references"))

                response = sanitise_response(response)

    return {
        "messages": [response],
        "product_qna_agent": {
            "iteration": state.product_qna_agent.iteration + 1,
            "final_answer": final_answer
        },
        "answer": answer,
        "references": references
    }

# %% [markdown]
# Shopping Cart Agent

# %%
class FinalAgentResponse(BaseModel):

    answer: str = Field(description="Answer to the question")

# %%
@traceable(
    name="shopping_cart_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def shopping_cart_agent(state) -> dict:
    
    prompt_template = """You are a part of the shopping assistant that can manage the user's shopping cart.

## Instructions

- Use names specificly provided in the available tools. Don't add any additional text to the names.
- You can run multiple tools at once.
- As the final answer you should return an answer in a form of actions performed.

## Additional information about the user

- User ID: {{ user_id }}
- Cart ID: {{ cart_id }}
"""

    template = Template(prompt_template)

    prompt = template.render(
        user_id=state.user_id,
        cart_id=state.cart_id
    )

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [get_shopping_cart, remove_from_cart, add_to_shopping_cart, FinalAgentResponse],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *state.messages
        ]
    )

    final_answer = False
    answer = ""

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")

                response = sanitise_response(response)

    return {
        "messages": [response],
        "shopping_cart_agent": {
            "iteration": state.shopping_cart_agent.iteration + 1,
            "final_answer": final_answer
        },
        "answer": answer
    }

# %% [markdown]
# ### Warehouse Manager Agent

# %%
@traceable(
    name="warehouse_manager_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def warehouse_manager_agent(state) -> dict:
    
    prompt_template = """You are a part of the shopping assistant that can manage available inventory in the warehouses.

## Instructions

- As the final answer you should return an answer to the users query in a form of actions performed.
- You must always check the availability of the items in the warehouses before reserving them.
- Only reserve items in warehouses if entire order can be reserved or the user has confirmed that they want a partial reservation.
- If you cannot reserve any items, return an answer that the order cannot be reserved.
- If you can reserve some items, return an answer that the order can be partially reserved and include the details.
- If only partial quantity can be reserved in some warehouses, try to combine the required quantity from different warehouses.
- Try to reserve items from the closest warehouse to the user first if users location is provided.
- As the final answer you should return an answer in a form of actions performed.
"""

    template = Template(prompt_template)

    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [check_warehouse_availability, reserve_warehouse_items, FinalAgentResponse],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *state.messages
        ]
    )

    final_answer = False
    answer = ""

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")

                response = sanitise_response(response)

    return {
        "messages": [response],
        "warehouse_manager_agent": {
            "iteration": state.warehouse_manager_agent.iteration + 1,
            "final_answer": final_answer
        },
        "answer": answer
    }

# %% [markdown]
# ### Coordinator Agent

# %%
class Delegation(BaseModel):
    agent: str = Field(description="The agent to delegate the task to.")
    task: str = Field(description="The task to be performed by the agent.")

class Plan(BaseModel):
    next_agent: str = Field(description="The next agent to invoke")
    plan: List[Delegation] = Field(description="A list of delegations to agents with tasks to be performed in sequence.")

# %%
@traceable(
    name="coordinator_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def coordinator_agent(state) -> dict:
    
    prompt_template = """You are a Coordinator Agent as part of a shopping assistant.

## Instructions

- Your role is to create plans for solving user queries and delegate the tasks accordingly.
- You will be given a conversation history, your task is to create a plan for solving the user's query.
- After the plan is created, you should output the next agent to invoke and the task to be performed by that agent.
- Once an agent finishes its task, you will be handed the control back, you should then review the conversation history and revise the plan.
- If there is a sequence of tasks to be performed by a single agent, you should combine them into a single task.
- Do not route to any agent if the user's query needs clarification or is irelevant. Do it yourself.

## Available Agents

- product_qna_agent: The user is asking a question about a product. This can be a question about available products, their specifications, user reviews etc.
- shopping_cart_agent: The user is asking to add or remove items from the shopping cart or questions about the current shopping cart.
- warehouse_manager_agent: The user is asking to reserve items from the warehouses or about availability of the items in warehouses.

## Examples

Question: "Do you have running shoes under $100?"
Next agent: product_qna_agent

Question: "Can you list the items in my cart?"
Next agent: shopping_cart_agent

Question: "Can you reserve my shopping cart?"
Next agent: warehouse_manager_agent
"""

    template = Template(prompt_template)

    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [FinalAgentResponse, Plan],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *state.messages
        ]
    )

    final_answer = False
    answer = ""
    plan = []
    next_agent = ""

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        if response.tool_calls[0].get("name") == "Plan":
            plan = response.tool_calls[0].get("args").get("plan")
            next_agent = response.tool_calls[0].get("args").get("next_agent")
            response = None
        else:
            for tool_call in response.tool_calls:
                if tool_call.get("name") == "FinalAgentResponse":
                    final_answer = True
                    answer = tool_call.get("args").get("answer")

                    response = sanitise_response(response)

    return {
        "messages": [response] if response else [],
        "coordinator_agent": {
            "iteration": state.coordinator_agent.iteration + 1,
            "final_answer": final_answer,
            "plan": plan,
            "next_agent": next_agent
        },
        "answer": answer
    }

# %% [markdown]
# Router Nodes

# %%
def product_qna_agent_tool_router(state) -> str:

    if state.product_qna_agent.final_answer:
        return "end"
    elif state.product_qna_agent.iteration > 5:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %%
def shopping_cart_agent_tool_router(state) -> str:

    if state.shopping_cart_agent.final_answer:
        return "end"
    elif state.shopping_cart_agent.iteration > 4:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %%
def warehouse_manager_agent_tool_router(state) -> str:

    if state.warehouse_manager_agent.final_answer:
        return "end"
    elif state.warehouse_manager_agent.iteration > 4:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %%
def coordinator_agent_edge(state) -> str:

    if state.coordinator_agent.final_answer:
        return "end"
    elif state.coordinator_agent.iteration > 6:
        return "end"
    elif state.coordinator_agent.next_agent == "product_qna_agent":
        return "product_qna_agent"
    elif state.coordinator_agent.next_agent == "shopping_cart_agent":
        return "shopping_cart_agent"
    elif state.coordinator_agent.next_agent == "warehouse_manager_agent":
        return "warehouse_manager_agent"
    else:
        return "end"

# %% [markdown]
# Graph Construction

# %%
class AgentProperties(BaseModel):
    iteration: int = 0
    final_answer: bool = False

class CoordinatorAgentProperties(BaseModel):
    iteration: int = 0
    final_answer: bool = False
    plan: List[Delegation] = []
    next_agent: str = ""

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    user_intent: str = ""
    product_qna_agent: AgentProperties = AgentProperties()
    shopping_cart_agent: AgentProperties = AgentProperties()
    warehouse_manager_agent: AgentProperties = AgentProperties()
    coordinator_agent: CoordinatorAgentProperties = CoordinatorAgentProperties()
    answer: str = ""
    references: list[RAGUsedContext] = []
    user_id: str = ""
    cart_id: str = ""

# %%
workflow = StateGraph(State)

product_qna_agent_tools = [get_formatted_item_context, get_formatted_reviews_context]
product_qna_agent_tool_node = ToolNode(product_qna_agent_tools)

shopping_cart_agent_tools = [get_shopping_cart, remove_from_cart, add_to_shopping_cart]
shopping_cart_agent_tool_node = ToolNode(shopping_cart_agent_tools)

warehouse_manager_agent_tools = [check_warehouse_availability, reserve_warehouse_items]
warehouse_manager_agent_tool_node = ToolNode(warehouse_manager_agent_tools)

workflow.add_node("product_qna_agent_tool_node", product_qna_agent_tool_node)
workflow.add_node("shopping_cart_agent_tool_node", shopping_cart_agent_tool_node)
workflow.add_node("warehouse_manager_agent_tool_node", warehouse_manager_agent_tool_node)
workflow.add_node("product_qna_agent", product_qna_agent)
workflow.add_node("shopping_cart_agent", shopping_cart_agent)
workflow.add_node("warehouse_manager_agent", warehouse_manager_agent)
workflow.add_node("coordinator_agent", coordinator_agent)

workflow.add_edge(START, "coordinator_agent")

workflow.add_conditional_edges(
    "coordinator_agent",
    coordinator_agent_edge,
    {
        "product_qna_agent": "product_qna_agent",
        "shopping_cart_agent": "shopping_cart_agent",
        "warehouse_manager_agent": "warehouse_manager_agent",
        "end": END
    }
)

workflow.add_conditional_edges(
    "product_qna_agent",
    product_qna_agent_tool_router,
    {
        "tools": "product_qna_agent_tool_node",
        "end": "coordinator_agent"
    }
)

workflow.add_conditional_edges(
    "shopping_cart_agent",
    shopping_cart_agent_tool_router,
    {
        "tools": "shopping_cart_agent_tool_node",
        "end": "coordinator_agent"
    }
)

workflow.add_conditional_edges(
    "warehouse_manager_agent",
    warehouse_manager_agent_tool_router,
    {
        "tools": "warehouse_manager_agent_tool_node",
        "end": "coordinator_agent"
    }
)

workflow.add_edge("product_qna_agent_tool_node", "product_qna_agent")
workflow.add_edge("shopping_cart_agent_tool_node", "shopping_cart_agent")
workflow.add_edge("warehouse_manager_agent_tool_node", "warehouse_manager_agent")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Test the Agent

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# Multiturn Conversation

# %%
initial_state = {
    "messages": [HumanMessage(content="Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion? Can you then add the best reviewed items from each category to my cart and reserve them in your warehouses?")],
    "user_id": "failure-mode-discovery-01",
    "cart_id": "failure-mode-discovery-01"
}
config = {
    "configurable": {
        "thread_id": "failure-mode-discovery-01"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_1 = chunk[1]

# %%
result_1
# Out:
# {'messages': [HumanMessage(content='Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion? Can you then add the best reviewed items from each category to my cart and reserve them in your warehouses?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content=[{'id': 'rs_048e210673ffa1e3006a7113a50ac081998cce9f453fdb090c', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqcROm2two56WdcWKmd03s1LpOYI9bCBP01q-pKm9MUcXqI6T5hcvDnHL3TR8HkXXpKSy87KiOtFzELF2G_8OtJWxZxSTPwm60jPvNrsjpAWnFUsqcNnlE1xXaVghg05AAllmE3WoW0c49RaxeP4CWKgDBvfG8YweId2j5bnLzUsegiyhJMBAtjkTWKNCU3kj0DXo0HWPnmOkuKeVb0SZpnzLWxn5GfVS9YJG7CHyiEpg8siFwzNt6k_zSWjjuwi4vEXMD_wXg5fXqQ9Z-1bT1C2DBbQAw2wz8tO-m5VnYppR9yBbOwWigU45pd7pwPidZxX4BT0sb8Cadzldd7IZVRQyb_iqasdAnmW4gaZpf0PdvAvA5-N0poEw7DPjPWpudYAMTkBUxRG7AsYqRiPypxHch7U3Y4pIQRNrv-NPLW1_JsixNlPzGY7bsaoGJroHu4uxPCWUlPV6VkjDJDM1g89oOHVR0uMa6mqUSL848g7tSrpJtnKz2b8DyAi74O5EgvltenUaX8sdWZi0eM5rVhWsAyIs_F2mP8p3MFA0F6JgoHS-emubkXi6w9MpAKafo4GNphb0lqO2V8bS8sKlqiOQlZXVI-_ZWuznNiiB8Eh23xvHk27SrSKGxp4ccQmnpcAF-QcV7QRRyfrmA9fCnXvBSYvS1bV7SsoiUYgeQ3SgpaYrPu9alEKhz246UDmJ4ySFZRtSUrPk8AwkiLdNGCwMQh8forXK1pKSqHEAfYayEpLtaRX6oWqksr-eVlKSoacxQwhhWKtmmQUMX1pDNN5C39N_SO5aQzl-Oj7MqLcUUBd-pi3DfnQpWgrQM64XbnwN3lu1-zx_EJsjTUz_3HCCf4M_qIMyVnsbZKmGLOvM7SPtgYZnJojZzJey2M-dgcMVlxpfSqske8qX6NqHWNG5WX11RRpR9kbMm0GbDqNx5hQ3n_yeyguD3hkuktL2wH-YLXt0yHsh396DTs5NsAzDukEACttd4AUgmD-qSCtYY4SHF9iCPMrO3dEFtc7uuwXlIFDMaV9emgni8I5VlQhipp-4_cHZAFu0JRgeVGE-WvC6qU5hW2YSAHIlMeIriXNJZzlRcxqCKALDaB_2YRZIlw9_5c8_0rfkyVWB5oUEZXudxKiwcaFjxxLAVk44OXdU1_iCpJ5zlj9WTmdFWJEwIt3qL8HMx07BQP8hcs_ClGQg='}, {'arguments': '{"query":"Earphones", "top_k":5}', 'call_id': 'call_dDxEibjfDq7wUspmxelkZRI2', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_048e210673ffa1e3006a7113a5ad748199bdc3f12978ddbf94', 'status': 'completed'}, {'arguments': '{"query":"Laptop", "top_k":5}', 'call_id': 'call_1CSNgzY9VBPj4o3MBLjWcWi8', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_048e210673ffa1e3006a7113a5ad9c819989c885e7621c7577', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_048e210673ffa1e3006a7113a45718819991d7c41161b62447', 'created_at': 1785795492.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_048e210673ffa1e3006a7113a45718819991d7c41161b62447', tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'Earphones', 'top_k': 5}, 'id': 'call_dDxEibjfDq7wUspmxelkZRI2', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Laptop', 'top_k': 5}, 'id': 'call_1CSNgzY9VBPj4o3MBLjWcWi8', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 748, 'output_tokens': 108, 'total_tokens': 856, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 39}}),
#   ToolMessage(content="- ID: B0BQLV7TSJ, rating: 3.7, description: Headphones Earbuds \n- ID: B0BB7JD7DD, rating: 4.6, description: Lrecat Wireless Earbud, Bluetooth 5.3 Headphones with CVC8.0 HD Mics, 32H Playtime Bluetooth Earphones with Hi-Fi Stereo Sound, Wireless Headphones in Ear IP7 Waterproof, Mini Ear Bud for Android iOS Bluetooth 5.3 and Effortless Pairing: Lrecat Bluetooth Earbud adopts advanced Bluetooth 5.3 technique and dual-channel transmission, which offer you faster transmission speed, stronger connection stability and longer Bluetooth range. Once taken from the charging case, Wireless Ear bud will be paired with the last-paired device automatically. CVC8.0 Superior Clear Call: Wireless Earphones with Mic support the mono mode and dual stereo mode, you can share J52 Earphones during meeting, calling and listening music. Each earbud has a build-in microphone for phone calls. CVC8.0 HD clear call can make the call more clearer. Extended Playtime: Wireless Bluetooth Earbud lasts for 6-8Hrs from a single charge and the included charging case provides an additional 3-4 times charges. Finally the Earphones in-Ear provides 32Hrs using time in total with a charging case. Charging with the USB-C charging cable that came with the Heaphones, and it can be fully charged in 1 hour. Immersive Stereo Sound and Real-Time Dual LED Display: Lrecat Bluetooth Earphones in Ear with 13mm dynamic speakers and triple-layer composite diaphragms provide more enjoyable music experience. Digital LED display shows the power level of the charging case and Earbud. When charging for the case, the LED light will start to flash from 1 to 100 Ultra-Light Earbud: The pocket-sized charging case does not take up much space to carry and you will not have any pressure on wearing the 3g ultra-light ear buds a long time. The ergonomic design provides a comfortable and secure fit that doesn’t protrude from your ears, especially for sports, work out and gym.\n- ID: B0C5M2SLKL, rating: 4.6, description: Wireless Earbuds Bluetooth 5.3 Headphones 42Hrs Playtime in Ear Buds Sports Earphones with Hi-Fi Stereo, Over-Ear Earhooks Headset with Dual LED Display/IP7 Waterproof/Noise Cancelling for Workout 2023 Newest Bluetooth 5.3 & One-Step Pairing ：Wireless earbuds adopt chip version 5.3 which provides stable transmission, resists interference strongly. Low latency and stable signal promise smooth using experience whether you are watching a movie or listening to music. And you just take the ear buds out of the charging case and they'll automatically connect to your phone after the first pairing. Dual LED Display & 42H Playback : With Dual LED display make it obvious to show the battery power of the case and Bluetooth earbuds. The remaining power in percentage on the screen is shown in the middle of the Bluetooth headphones, and the charging process of the earbuds is displayed on both sides. During Charging, the LED indicator light will flash. Besides, 500mAh charging case supports 5 times fully charging for wireless ear buds and let you enjoy more than 42 hours music time. Comfortable for Sports & IP7 Waterproof : I27 in ear earphones are equipped with soft and flexible earhooks, 3 different sizes of ear tips for your best choice, which ensure the headphones will stay comfortably firm in place and won't fall off, you won't feel tired after long time wearing. And these Bluetooth earphones are rating at IP7 waterproof, the nano-coating on earbuds surface can prevent water and sweat from penetrating. Note: Not supported for use while swimming. Smart Touch Control & Wide Compatibility : By touching wireless earphones to answer the phone and hang up the phone, music play/pause, music up and down , volume up/down, or access to other functions, the operation is very simple and convenient. Compared with physical button, it largely minimizes the pressure to your ears. Meanwhile, it compatible with most Bluetooth-enabled devices, including IOS, Android smartphones, Lapto ...
#   ToolMessage(content='- ID: B0C18D24G9, rating: 4.1, description: ECOHERO 2023 Laptop, 14" 1920x1080 FHD IPS Screen, 12GB DDR4 RAM/256GB NVMe SSD, Intel N5095 Quad Core, Windows 11 laptops Computers, 2.4G/5G WiFi, Bluetooth 4.2, Support Type c PD3.0 Fast Charging 【Processor】11th Gen Intel Celeron Processor N5095 Quad-Core Quad-Threads 2.0GHz Processor (4M Cache, up to 2.90 GHz), Intel UHD Graphics, 10 nm Technology, TDP: 15 W. 【Memory & Storage】Built-in 12GB DDR4 high-frequency memory, fast response, helps to release better performance, multiple applications run at the same time without freezing, 256GB NVMe high-speed SSD, compared with ordinary SATA SSD, the read and write speed is increased by 5 times, up to 2000MB/S above. 【Screen】14" FHD IPS screen (1920 x 1080) Display, the picture is detailed and realistic, rich in color, presenting a clear and colorful world. 【Ports】 1 x USB 3.2 Gen 1, 2 x USB2.0, 1 x Full-featured Type-C (Support PD3.0 fast charge), 1 x Headphone Jack, 1 x Micro SD ( Supports up to 256GB ), 1 x DC, 1 x HD (Support HD output HD video), Built-in 2.4G and 5G dual-band WIFI, Bluetooth 4.2, Dual stereo speakers and Dual array microphone. 【System】The laptop comes with the latest version of windows 11 Pro pre-installed to help improve your productivity.\n- ID: B0C9ZWCZ99, rating: 4.3, description: HP 15.6" HD Busienss Laptop Newest, 6-core AMD Ryzen 5 5500U(up to 4.0GHz), 8GB RAM, 256GB SSD, USB-A&C, WiFi, Fast Charge, Windows 11 + GM Accessory 【15.6" HD micro-edge Display】Revolutionize your display and see more of what you love with this slim bezel design that maximizes your viewing area foor an immersive multimedia experience. 【AMD Ryzen 5 5500U Mobile Processor】Create. Play. Work. Educate. Entertain. The possibilities are infinite. Be anywhere, go anywhere. Powers ultrathin notebooks that offer supreme performance, astonishing battery life, and modern features you need on-the-go. 【Upgraded to 8GB system memory for advanced multitasking】Substantial high-bandwidth RAM to smoothly run your games and photo and video-editing applications, as well as multiple programs and browser tabs all at once. 【Upgraded to 256GB SSD Storage】Boot up in seconds, get to files faster, and have room for loads of files with the lightning-quick solid state drive. 【Windows 11 Home】Windows 11 is the place to think, express, and create in a natural way. 2 x USB-A; 1 x USB-C; 1XHDMI.\n- ID: B0B232NZJL, rating: 4.4, description: 2022 Newest HP 14 Laptop, 14" HD IPS Display, AMD Ryzen 3 3250U Processor, AMD Radeon Graphics, 8GB RAM, 128GB SSD, USB Type-C, HDMI, Long Battery Life Up to 10 Hours, Windows 11 + Microfiber Cloth 【Storage & RAM】Enjoy up to 15x faster performance than a traditional hard drive with 128 GB M.2 SSD storage and experience improved multitasking with higher bandwidth thanks to 8 GB of RAM 【Processor】AMD Ryzen 3 3250U 3.50GHz Dual-Core Processor (4 MB L3 cache, 2 cores, 4 threads) 【Display】14" HD LED 220nits IPS Display, BrightView, micro-edge 【Fast Charge】Go from 0 to 50% charge in approximately 45 minutes 【Bundled Accessory】Microfiber Cloth\n- ID: B09J52P1TD, rating: 4.4, description: HP 17.3" Flagship HD+ Business Laptop, Intel Quad Core i3-1125G4(Beat i5-1035G4), 8GB RAM, 256GB PCIe SSD, Bluetooth, HDMI, Webcam, Windows 11, Silver, w/GM Accessories 【11th Gen Intel Core i3-1125G4 】2.0 GHz base frequency, up to 3.7 GHz with Intel Turbo Boost Technology, The 11th gen dual-core laptop brings the perfect combination of features to make you unstoppable. This is an ideal home office laptop to get things done fast with high performance, instant responsiveness and best-in-class connectivity. 【17.3" HD+(1600x900) Anti-Glare LED IPS Non-Touch Display】17.3-inch diagonal, HD+, BrightView, 220 nits, 60% NTSC，boasts impressive color and clarity. Energy-efficient LED .Enjoy vibrant, crystal-clear images with Non-reflective and low gloss means you\'ll get less glare while you\'re outside 【 RAM & SSD】8 GB DDR4 RAM, 256GB PCIe NVMe ...
#   AIMessage(content=[{'id': 'rs_048e210673ffa1e3006a7113a8f0cc819991290182e6f71260', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABq
 'type': 'function_call', 'id': 'fc_048e210673ffa1e3006a7113aa6a2081998ef03b7486f3f9b3', 'status': 'completed'}, {'arguments': '{"query":"performance display battery build quality and negatives", "parent_asins":["B0B232NZJL"],"top_k":20}', 'call_id': 'call_kzBltGhmfnC5f2p3e8iV2KGI', 'name': 'get_formatted_reviews_context', 'type': 'function_call', 'id': 'fc_048e210673ffa1e3006a7113aa6a288199a72e6a496d359cbe', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_048e210673ffa1e3006a7113a821a88199a9aa112d5489b0c8', 'created_at': 1785795496.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_048e210673ffa1e3006a7113a821a88199a9aa112d5489b0c8', tool_calls=[{'name': 'get_formatted_reviews_context', 'args': {'query': 'positive and negative reviews', 'parent_asins': ['B0C13M8GJZ', 'B0B232NZJL'], 'top_k': 20}, 'id': 'call_WdZkIacOxtyP3ce04uRzlMlX', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'query': 'sound quality battery comfort call quality and negatives', 'parent_asins': ['B0C13M8GJZ'], 'top_k': 20}, 'id': 'call_NlZvWyMDutSpkhtfwejEv71R', 'type': 'tool_call'}, {'name': 'get_formatted_reviews_context', 'args': {'query': 'performance display battery build quality and negatives', 'parent_asins': ['B0B232NZJL'], 'top_k': 20}, 'id': 'call_kzBltGhmfnC5f2p3e8iV2KGI', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 4349, 'output_tokens': 273, 'total_tokens': 4622, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 117}}),
#   ToolMessage(content="- ID: B0B232NZJL, user review: Good Good\n- ID: B0C13M8GJZ, user review: Surprisingly nice The touch controls are the nicest of any earbuds I have ever owned, huge props on that. The battery indicator is a very welcome feature. Battery life is amazing. Lasts about 5 hrs per earbud and I can recharge the earbuds at least 4 times. The low bass absolutely Slams! Shape, fit & the materials used are fantastic. Very high quality. These are my new favorite. Now for the downside. And there is only 1.  The low mid range (180-240hz) is too strong. On very specific songs it’s very noticeable. Those songs don’t come up often so these will be replacing my skull candy dime earbuds that I buy every month as I work in harsh conditions.\n- ID: B0C13M8GJZ, user review: Works well Works well!!!\n- ID: B0B232NZJL, user review: Good product I bought this laptop a month ago after the HP laptop I've had for over 4 years broke down. I like the speed of the laptop overall and the amount of space, however I do miss having a back lit keyboard and a touchscreen. I rely heavily on my laptop as I use it to play, do homework, work, and other necessities. 1 month in it hasn't failed me.<br /><br />There is one thing I HATE this laptop shuts itself down if I haven't used it in a few hours. This is the reason it lost one star. The specs were all true, but I wish there was a way to stop this from happening.\n- ID: B0B232NZJL, user review: No problems Great laptop. Exactly what was advertised. No problems.\n- ID: B0B232NZJL, user review: Great products fast delivery thank u seller Fast delivery great quality\n- ID: B0B232NZJL, user review: Keyboard Difficult to Read This model DOES NOT have a backlit keyboard.  The keyboard is not legible even in good light. Very disappointing - Here is a potential work around - https://www.amazon.com/dp/B07SLRTCSD?psc=1&ref=ppx_yo2ov_dt_b_product_details\n- ID: B0B232NZJL, user review: Really good buy All the specifications are accurate, it's easy to carry, the sound is good and tje battery life is impressive. You coukd be using it for hrs and when you check it's only at 50% it amazes me all the time. I never have to rush for my charger.\n- ID: B0C13M8GJZ, user review: awesome and great price I bought it for my niece and she’s really like the color and digital display. It can use it immediately and just connect to the Bluetooth. Quality exceeds its value\n- ID: B0C13M8GJZ, user review: Nice sound priced terrific. They pair with any bluetooth device great and are quick to recharge. The earphones and case aren't quite as sturdy as airpods but for the cost they are a close second. The visibility on the display is very useful for % life remaining and I'm happy with the distance range too.\n- ID: B0C13M8GJZ, user review: Great quality! I bought these for my 7 year old daughter as a reward and he absolutely loves them. Packaging is neat and the item arrived quickly. Sound is great. He even called me using them and I could clearly hear him. They came charged, so he was able to use them immediately. Definitely would purchase again.\n- ID: B0B232NZJL, user review: Noisy The ventilation is too noisy. The aspect of the laptop is that it is too fragile. It came with Windows on the S mode although it didn’t say in the add.\n- ID: B0B232NZJL, user review: You can always trust HP. very easy set up. Battery is good. Very reasonably priced. Very good product, no problems whatsoever.\n- ID: B0B232NZJL, user review: light  weight touch  sreen\n- ID: B0B232NZJL, user review: Love this laptop [[VIDEOID:27d2b249b20a8cd1bb48a7aed3436dba]] Its defiantly an amazing laptop that i use for all my school assignments and programming . The screen quality is amazing and wide . It worth the value for this wide screen and the amount of space it has.\n- ID: B0C13M8GJZ, user review: GREAT VALUE EAR BUDS! SLEEK FINISH!! [[VIDEOID:7d659e2fe1308d1b486f239c1585e5c8]]\n- ID: B0C13M8GJZ, user review: Easy to setup and works well Setup took 5 seco ...
#   ToolMessage(content="- ID: B0C13M8GJZ, user review: Surprisingly nice The touch controls are the nicest of any earbuds I have ever owned, huge props on that. The battery indicator is a very welcome feature. Battery life is amazing. Lasts about 5 hrs per earbud and I can recharge the earbuds at least 4 times. The low bass absolutely Slams! Shape, fit & the materials used are fantastic. Very high quality. These are my new favorite. Now for the downside. And there is only 1.  The low mid range (180-240hz) is too strong. On very specific songs it’s very noticeable. Those songs don’t come up often so these will be replacing my skull candy dime earbuds that I buy every month as I work in harsh conditions.\n- ID: B0C13M8GJZ, user review: Nice sound priced terrific. They pair with any bluetooth device great and are quick to recharge. The earphones and case aren't quite as sturdy as airpods but for the cost they are a close second. The visibility on the display is very useful for % life remaining and I'm happy with the distance range too.\n- ID: B0C13M8GJZ, user review: Great quality! I bought these for my 7 year old daughter as a reward and he absolutely loves them. Packaging is neat and the item arrived quickly. Sound is great. He even called me using them and I could clearly hear him. They came charged, so he was able to use them immediately. Definitely would purchase again.\n- ID: B0C13M8GJZ, user review: So easy to use. First off the pics don’t do it justice this green color is amazing. The ease of use is great went straight into pairing mode when the case is opened and the sound quality rivals so better name brand ones that I have. My son will love them and I love that there so nice and priced reasonable.\n- ID: B0C13M8GJZ, user review: Love it! I bought this pair of Bluetooth earbuds because only this kind of head fits my ears well. It was exactly what I expected, tight and comfortable to wear. Super convenient to set up, charge and use, clear sound by the way. It's well deserved.\n- ID: B0C13M8GJZ, user review: Easy to setup and works well Setup took 5 seconds without reading the manual. The battery was charged at 90% so that was great. USB-C charger was great so charging was a breeze.<br /><br />Great value for money.\n- ID: B0C13M8GJZ, user review: GREAT VALUE EAR BUDS! SLEEK FINISH!! [[VIDEOID:7d659e2fe1308d1b486f239c1585e5c8]]\n- ID: B0C13M8GJZ, user review: Wireless Earbuds! I got these wireless earbuds to listen to music and do house chores at home, which these are awsome for! These wireless earbuds are tiny, which is good to bring to anywhere like the gym too! These earbuds are tiny and affordable! Would recommend. The color is bright green, which is very beautiful and makes it easy to find!\n- ID: B0C13M8GJZ, user review: awesome and great price I bought it for my niece and she’s really like the color and digital display. It can use it immediately and just connect to the Bluetooth. Quality exceeds its value\n- ID: B0C13M8GJZ, user review: 13-year-old loves them! Awesome color and quality for a set of headphones under $30! My 13-year-old love to wear them so the rest of us can be spared from hours of listening to Weird Al.\n- ID: B0C13M8GJZ, user review: Perfect!! Easy to set up and great quality!\n- ID: B0C13M8GJZ, user review: Earbuds for gym I’m not rich enough to afford an apple airpod so bought this for my little cousin who workout at gym. He love the sound and since it’s waterproof he use it in suana room.  The price for the product is awesome.\n- ID: B0C13M8GJZ, user review: Works well Works well!!!\n", name='get_formatted_reviews_context', tool_call_id='call_NlZvWyMDutSpkhtfwejEv71R'),
#   ToolMessage(content="- ID: B0B232NZJL, user review: Good product I bought this laptop a month ago after the HP laptop I've had for over 4 years broke down. I like the speed of the laptop overall and the amount of space, however I do miss having a back lit keyboard and a touchscreen. I rely heavily on my laptop as I use it to play, do homework, work, and other necessities. 1 month in it hasn't failed me.<br /><br />There is one thing I HATE this laptop shuts itself down if I haven't used it in a few hours. This is the reason it lost one star. The specs were all true, but I wish there was a way to stop this from happening.\n- ID: B0B232NZJL, user review: Really good buy All the specifications are accurate, it's easy to carry, the sound is good and tje battery life is impressive. You coukd be using it for hrs and when you check it's only at 50% it amazes me all the time. I never have to rush for my charger.\n- ID: B0B232NZJL, user review: You can always trust HP. very easy set up. Battery is good. Very reasonably priced. Very good product, no problems whatsoever.\n- ID: B0B232NZJL, user review: Sadly after only a few times of using it goes blank! I had high hopes but the screen keeps going black. I plan to contact the manufacturer!\n- ID: B0B232NZJL, user review: Keyboard Difficult to Read This model DOES NOT have a backlit keyboard.  The keyboard is not legible even in good light. Very disappointing - Here is a potential work around - https://www.amazon.com/dp/B07SLRTCSD?psc=1&ref=ppx_yo2ov_dt_b_product_details\n- ID: B0B232NZJL, user review: light  weight touch  sreen\n- ID: B0B232NZJL, user review: Noisy The ventilation is too noisy. The aspect of the laptop is that it is too fragile. It came with Windows on the S mode although it didn’t say in the add.\n- ID: B0B232NZJL, user review: keyboard is not back lit. Very nice laptop.  Fast processor.  Quick to boot.  But the keyboard is not back lit.\n- ID: B0B232NZJL, user review: Love this laptop [[VIDEOID:27d2b249b20a8cd1bb48a7aed3436dba]] Its defiantly an amazing laptop that i use for all my school assignments and programming . The screen quality is amazing and wide . It worth the value for this wide screen and the amount of space it has.\n- ID: B0B232NZJL, user review: Change SSD had to change my SSD out with in 6 months other than that it has been great. Cant find where the RAM card is\n- ID: B0B232NZJL, user review: No problems Great laptop. Exactly what was advertised. No problems.\n- ID: B0B232NZJL, user review: Laptop for Fluke toolbag I needed a laptop for for the Fluke Pack30 tool backpack that I recently purchased from Amazon.  While there are many great tool bags, the Fluke bag provided the desired pockets for my test equipment.  However, it limits your laptop to no more than 12 inches in width.  Since I did not want to struggle pulling it out, I looked for something in the 11 inch width range.<br /><br />I found this laptop on Amazon and it meet what I like for field service work.  It has a decent processor, memory and sizeable solid state drive.  Plus it is also a 2-1 laptop so that it functions as a tablet with touch screen.  To top it off, I felt the price was very good and a brand that I felt comfortable with.<br /><br />I ordered the laptop in the afternoon with a next day shipping promise.  It got here the next morning at 5:30 am.  IMPRESSIVE work Amazon!!!<br /><br />The seller professionally double-packed my new laptop and it powered up flawlessly.  I am very impressed with the performance and quality of this laptop.<br /><br />Just a note - I only plan on using this for work and typically only use Office.  I do not plan on using this for gaming or video intense applications and can not make any comments to this use.  However, I am sure it is great for video streaming.\n- ID: B0B232NZJL, user review: CPU ghz is NOT ACCURATE As you can see in the photo, I paid for 3.5 ghz, computer is only running 2.6<br />False advertising if you ask me. Price is not accurat ...
#   AIMessage(content='Here are the best-reviewed options I found in each category, plus a quick summary of what people liked and disliked.\n\n**Earphones**\n- **Jesebang Wireless Earbud (ID: B0C13M8GJZ, rating 4.9)**\n- Noted positives from reviews:\n  - Strong battery life\n  - Easy pairing and setup\n  - Comfortable fit\n  - Clear sound and good bass\n  - Useful battery indicator / LED display\n- Noted negatives from reviews:\n  - One review said the low mid range can be too strong on some songs\n  - Another review said they are not as sturdy as AirPods\n\n**Laptop**\n- **HP 14 Laptop with AMD Ryzen 3 3250U, 8GB RAM, 128GB SSD (ID: B0B232NZJL, rating 4.4)**\n- Noted positives from reviews:\n  - Fast enough for school, work, and basic use\n  - Good battery life\n  - Easy setup\n  - Lightweight and easy to carry\n  - Good screen quality / value for the price\n- Noted negatives from reviews:\n  - Several reviews mention no backlit keyboard\n  - One review says it can shut down after being unused for a while\n  - One review mentions noisy ventilation / fragility\n  - A few reviews complain about misleading specs or S mode\n\nI can’t actually add items to your cart or reserve warehouse stock from here. If you want, I can still help you pick the better choice for your budget or use case.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content=[{'id': 'rs_048e210673ffa1e3006a7113b257d48199afde680acf9e5c98', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqcROzyabAjM8xj_1J0e7XcJDL7WvNwGQHsVTA6-BG02FpGnqr8-HbBotc2JUcblp0d5j3uXK77EEha7u-JsJSNwa7hFz09vtbL0-BKarlGDV9YfyO2DYAcxai_uOxFkzc9esYyUXO-yd5AcaITTGaR9nDvl3cHqYp75aqxAsOJOeTm6y9DatqAQfaAiZhtRrTC18fkHi2-gHvb4vE5Hnfit50TyhWbkTBInCn9ZFTNOh_lOX0Ry4yN4Py-kH8potvlCA_vwLl6fViT19Sf7v2yFKL7FeZyTgTTtFbS7SlxeBkjokimR_PBgNn4Y5Hts2ooqjfhX6d4wJ-ASMdl_bBDGNdmNFTOSr8tWvmrUICOP3-BYjNwlHTjmoNGhzs1J2rzmyK3t8XLt4unvWak9ifCbsEuMrjc7FQboab319F-XiUnwcp5nlkXMypZMuXvxUVfJe3oUCL4B_SdtcYVYnxfFw-LRQRtnhK8xOQoDyie8qfglx4n2zodlPvvS2wRQK_VRDSe7vxC12wTMViSoerx64ioWCJlwf9ePSin2qeagt6rGsM9
 'type': 'function_call', 'id': 'fc_048e210673ffa1e3006a7113b871a881998ed4bcca2bbd558b', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_048e210673ffa1e3006a7113b7ada48199901a2d52ce30541b', 'created_at': 1785795511.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_048e210673ffa1e3006a7113b7ada48199901a2d52ce30541b', tool_calls=[{'name': 'get_shopping_cart', 'args': {'user_id': 'failure-mode-discovery-01', 'cart_id': 'failure-mode-discovery-01'}, 'id': 'call_LR95H2PBZXx91EyuQTyFGtEg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 8939, 'output_tokens': 98, 'total_tokens': 9037, 'input_token_details': {'cache_read': 7552}, 'output_token_details': {'reasoning': 60}}),
#   ToolMessage(content="[{'product_id': 'B0B232NZJL', 'price': Decimal('309.00'), 'quantity': 1, 'currency': 'USD', 'product_image_url': 'https://m.media-amazon.com/images/I/41422+8IP4L._AC_.jpg', 'total_price': Decimal('309.00')}, {'product_id': 'B0C13M8GJZ', 'price': None, 'quantity': 1, 'currency': 'USD', 'product_image_url': 'https://m.media-amazon.com/images/I/41mdxa3CJlL._AC_.jpg', 'total_price': None}]", name='get_shopping_cart', tool_call_id='call_LR95H2PBZXx91EyuQTyFGtEg'),
#   AIMessage(content='Actions performed:\n- Selected the best-reviewed earphones: Jesebang Wireless Earbud (ID: B0C13M8GJZ, rating 4.9).\n- Selected the best-reviewed laptop: HP 14 Laptop with AMD Ryzen 3 3250U, 8GB RAM, 128GB SSD (ID: B0B232NZJL, rating 4.4).\n- Added both items to your cart.\n\nReview summary:\n- Earphones positives: strong battery life, easy pairing/setup, comfortable fit, clear sound, useful LED battery display.\n- Earphones negatives: some reviews mention the low mid range can be too strong and that the build is not as sturdy as premium brands.\n- Laptop positives: fast for school/work/basic use, good battery life, easy setup, lightweight, good value.\n- Laptop negatives: several reviews mention no backlit keyboard, some mention shutdowns after inactivity, noisy ventilation, and concerns about misleading specs/S mode.\n\nWarehouse reservation:\n- I’m unable to reserve warehouse stock from here, so that part could not be completed.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content=[{'id': 'rs_048e210673ffa1e3006a7113c115f88199bcb6d16a0cea5435', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqcRPCY_tizwM7gFCVA_OuUR-SXAvxULhZjgrh0XMQUbQD2r8VHTmmqA3dEnYRyzqKzMqEsNdAJD5jS3OmDBdI582f64XKGGesiXzNwh3m4XTSUCi_QOoHvIYWaDQPjQMIQFwtE--LcDpRkAEaSaoamcSbqvXn5QaA6-3J1wg0PL0Cp3R02MHDVLWfGCeW8Q85pKQJiDYM9vCFzXlwkNKV4y_hUVZsiKCOeUEMFjVCRqcZOTVS1Ae4MKm8vxQXc2FXeuXBmBQTjzqZUlpl3qUOs4SL-HFP0TTXygvCPQGrBFZytbwZCbyXALZCXByXZ7b_Pzooh08cyts0GGaluUNSSKWsf2-KVdj_wNBRA46NVskaQ3oPKcN01zjCBDHbax7zhSAUyc9OK5NfywbZTqWipo4s6NCH1JcPgINzZVICcfdAmgj3b2S_JVobc7eEyXjrMlqBiwi6BfOM9kllgzNT9WCIlLjiByVUsNCWLybmVhovXQ6YrObZKvAba-RkKjtxqf7SaMrIfFyR0lmniqeMYQCljFrQxkWCy1INrky0OixNwMy7RyU8dFc3fu1a57GkPjm1uVgZ84BgyYpAhw5Opp01wLxC1XR_cmrmzxBSepNK0Cta_jJzw71cc744aCZNyesu-9Q9SLcYDjrT4Le5c5fyvWQhNkKJh4nsloDHhQrbiABbECt_4bSSPmn6xtvaJGIXdWIUUlA7ohryTvjWu-jJqjrSuE45-wJJbBHqNQzpzAJMwy2wIOPQcTq9FVzniXruKN_f8oq6qkzQBNzBbLE0AdSEbri8VZuJ0vJemZbbl2QJXjoDMBHLnHJzAQGgw7zSc3-bsXhMFFTFIQgIaDtHpk195MadQeL18Zs1wgXhI6a50MvzWPTs1jH6poJRkUIyvvxvMVcQ9LJ1URDa0bwN_MbAxT_Z8QW3zcd8bQu-eaVH1p-xKMSzm7pzyRRmgghUthmL4KovmATmPILrPq28qxa000TEp2PS03huT2gubVVZcHHlPiLCBRTX_NjKTyJR2kJq5C_tzi03JgLSnY_pjz256pqKy8-ZRRTbnUNlVw='}, {'arguments': '{"items":[{"product_id":"B0C13M8GJZ","quantity":1},{"product_id":"B0B232NZJL","quantity":1}]}', 'call_id': 'call_54lZyUy66BQ9vd3PUYDNPrYq', 'name': 'check_warehouse_availability', 'type': 'function_call', 'id': 'fc_048e210673ffa1e3006a7113c19df48199aef3e99813d313e4', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_048e210673ffa1e3006a7113c0911881999d362db13daea50d', 'created_at': 1785795520.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_048e210673ffa1e3006a7113c0911881999d362db13daea50d', tool_calls=[{'name': 'check_warehouse_availability', 'args': {'items': [{'product_id': 'B0C13M8GJZ', 'quantity': 1}, {'product_id': 'B0B232NZJL', 'quantity': 1}]}, 'id': 'call_54lZyUy66BQ9vd3PUYDNPrYq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 9468, 'output_tokens': 123, 'total_tokens': 9591, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 69}}),
#   ToolMessage(content='{"can_fulfill_completely": true, "warehouses_full_fulfillment": [{"warehouse_id": "DE-BER-01", "warehouse_name": "Berlin Distribution Center", "warehouse_location": "Berlin, Germany"}, {"warehouse_id": "FR-LYO-01", "warehouse_name": "Lyon Regional Warehouse", "warehouse_location": "Lyon, France"}, {"warehouse_id": "DE-MUN-01", "warehouse_name": "Munich Logistics Hub", "warehouse_location": "Munich, Germany"}, {"warehouse_id": "FR-PAR-01", "warehouse_name": "Paris Central Depot", "warehouse_location": "Paris, France"}, {"warehouse_id": "FR-MAR-01", "warehouse_name": "Marseille Mediterranean Hub", "warehouse_location": "Marseille, France"}, {"warehouse_id": "DE-HAM-01", "warehouse_name": "Hamburg North Warehouse", "warehouse_location": "Hamburg, Germany"}], "warehouses_partial_fulfillment": [], "unavailable_items": [], "details": [{"warehouse_id": "DE-BER-01", "warehouse_name": "Berlin Distribution Center", "warehouse_location": "Berlin, Germany", "items": [{"product_id": "B0C13M8GJZ", "requested": 1, "available": 31, "can_fulfill_completely": true, "can_fulfill_partially": false}, {"product_id": "B0B232NZJL", "requested": 1, "available": 15, "can_fulfill_completely": true, "can_fulfill_partially": false}], "can_fulfill_all": true, "has_partial": false}, {"warehouse_id": "FR-LYO-01", "warehouse_name": "Lyon Regional Warehouse", "warehouse_location": "Lyon, France", "items": [{"product_id": "B0C13M8GJZ", "requested": 1, "available": 37, "can_fulfill_completely": true, "can_fulfill_partially": false}, {"product_id": "B0B232NZJL", "requested": 1, "available": 2, "can_fulfill_completely": true, "can_fulfill_partially": false}], "can_fulfill_all": true, "has_partial": false}, {"warehouse_id": "DE-MUN-01", "warehouse_name": "Munich Logistics Hub", "warehouse_location": "Munich, Germany", "items": [{"product_id": "B0C13M8GJZ", "requested": 1, "available": 52, "can_fulfill_completely": true, "can_fulfill_partially": false}, {"product_id": "B0B232NZJL", "requested": 1, "available": 93, "can_fulfill_completely": true, "can_fulfill_partially": false}], "can_fulfill_all": true, "has_partial": false}, {"warehouse_id": "FR-PAR-01", "warehouse_name": "Paris Central Depot", "warehouse_location": "Paris, France", "items": [{"product_id": "B0C13M8GJZ", "requested": 1, "available": 58, "can_fulfill_completely": true, "can_fulfill_partially": false}, {"product_id": "B0B232NZJL", "requested": 1, "available": 83, "can_fulfill_completely": true, "can_fulfill_partially": false}], "can_fulfill_all": true, "has_partial": false}, {"warehouse_id": "FR-MAR-01", "warehouse_name": "Marseille Mediterranean Hub", "warehouse_location": "Marseille, France", "items": [{"product_id": "B0C13M8GJZ", "requested": 1, "available": 32, "can_fulfill_completely": true, "can_fulfill_partially": false}, {"product_id": "B0B232NZJL", "requested": 1, "available": 33, "can_fulfill_completely": true, "can_fulfill_partially": false}], "can_fulfill_all": true, "has_partial": false}, {"warehouse_id": "DE-HAM-01", "warehouse_name": "Hamburg North Warehouse", "warehouse_location": "Hamburg, Germany", "items": [{"product_id": "B0C13M8GJZ", "requested": 1, "available": 33, "can_fulfill_completely": true, "can_fulfill_partially": false}, {"product_id": "B0B232NZJL", "requested": 1, "available": 58, "can_fulfill_completely": true, "can_fulfill_partially": false}], "can_fulfill_all": true, "has_partial": false}]}', name='check_warehouse_availability', tool_call_id='call_54lZyUy66BQ9vd3PUYDNPrYq'),
#   AIMessage(content=[{'id': 'rs_048e210673ffa1e3006a7113c318e881999d31a2568beada85', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqcRPFmcgrUWNBZx4wbmZuQ2wXetUGD_e20kiq-Y4mC2HYkEkLp_U_OgHzcoZkKG-HuLVu84P-cSaiiN2Khs131IsAKM-sPuP54WsIFXEgtvDp95WkTVmzSvaCgCCLlZxFlS9LVi_SFIEpQrX5QdhAA4c5mOgTFyjWS0toVArZgrjxt_IOUkaLKd29MP_IAV05yI5Zkpt-DygC78993_sr6dY9Zze0E2SSH2W_lCuQHMIBcJ1WHGmS54ZKXNtcPcJQIAaqe4XqDEiMnJN-pbF4mUhEijMDONZ4bdwrkQwLkLMXF7VWkJVeNTEzrShkV1wHQR5gqhkKuQGGmhNZlWrO4_ZQd_54iNQPd-
 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 46}}),
#   ToolMessage(content='{"success": true, "reserved_items": [{"product_id": "B0C13M8GJZ", "quantity": 1, "warehouse_id": "DE-BER-01", "warehouse_name": "Berlin Distribution Center", "warehouse_location": "Berlin, Germany"}, {"product_id": "B0B232NZJL", "quantity": 1, "warehouse_id": "DE-BER-01", "warehouse_name": "Berlin Distribution Center", "warehouse_location": "Berlin, Germany"}], "failed_items": []}', name='reserve_warehouse_items', tool_call_id='call_GyNaS4XVWg5VG728i2HxcZHz'),
#   AIMessage(content='Actions performed:\n- Selected the best-reviewed earphones: Jesebang Wireless Earbud (ID: B0C13M8GJZ, rating 4.9).\n- Selected the best-reviewed laptop: HP 14 Laptop with AMD Ryzen 3 3250U, 8GB RAM, 128GB SSD (ID: B0B232NZJL, rating 4.4).\n- Added both items to your cart.\n- Checked warehouse availability and confirmed both items can be fully fulfilled.\n- Reserved both items from Berlin Distribution Center (DE-BER-01).\n\nReview summary:\n- Earphones positives: strong battery life, easy pairing/setup, comfortable fit, clear sound, useful LED battery display.\n- Earphones negatives: some reviews mention the low mid range can be too strong and the build is not as sturdy as premium brands.\n- Laptop positives: fast for school/work/basic use, good battery life, easy setup, lightweight, good value.\n- Laptop negatives: several reviews mention no backlit keyboard, some mention shutdowns after inactivity, noisy ventilation, and concerns about misleading specs/S mode.\n\nReservation result:\n- Success: yes\n- Reserved items: 1 x B0C13M8GJZ and 1 x B0B232NZJL\n- Warehouse: Berlin Distribution Center, Berlin, Germany', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content='I selected the best-reviewed items in each category, added them to your cart, and reserved them in the Berlin Distribution Center.\n\nSelected items:\n- Earphones: Jesebang Wireless Earbud (ID: B0C13M8GJZ, rating 4.9)\n- Laptop: HP 14 Laptop with AMD Ryzen 3 3250U, 8GB RAM, 128GB SSD (ID: B0B232NZJL, rating 4.4)\n\nQuick review summary:\n- Earphones positives: strong battery life, easy pairing/setup, comfortable fit, clear sound, useful LED battery display.\n- Earphones negatives: some reviews mention the low mid range can be too strong and that the build is not as sturdy as premium brands.\n- Laptop positives: fast for school/work/basic use, good battery life, easy setup, lightweight, good value.\n- Laptop negatives: several reviews mention no backlit keyboard, some mention shutdowns after inactivity, noisy ventilation, and concerns about misleading specs/S mode.\n\nReservation:\n- Success: yes\n- Warehouse: Berlin Distribution Center (DE-BER-01)\n- Reserved: 1 x B0C13M8GJZ, 1 x B0B232NZJL', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'product_qna_agent': {'iteration': 3, 'final_answer': True},
#  'shopping_cart_agent': {'iteration': 4, 'final_answer': True},
#  'warehouse_manager_agent': {'iteration': 3, 'final_answer': True},
#  'coordinator_agent': {'iteration': 5,
#   'final_answer': True,
#   'plan': [],
#   'next_agent': ''},
#  'answer': 'I selected the best-reviewed items in each category, added them to your cart, and reserved them in the Berlin Distribution Center.\n\nSelected items:\n- Earphones: Jesebang Wireless Earbud (ID: B0C13M8GJZ, rating 4.9)\n- Laptop: HP 14 Laptop with AMD Ryzen 3 3250U, 8GB RAM, 128GB SSD (ID: B0B232NZJL, rating 4.4)\n\nQuick review summary:\n- Earphones positives: strong battery life, easy pairing/setup, comfortable fit, clear sound, useful LED battery display.\n- Earphones negatives: some reviews mention the low mid range can be too strong and that the build is not as sturdy as premium brands.\n- Laptop positives: fast for school/work/basic use, good battery life, easy setup, lightweight, good value.\n- Laptop negatives: several reviews mention no backlit keyboard, some mention shutdowns after inactivity, noisy ventilation, and concerns about misleading specs/S mode.\n\nReservation:\n- Success: yes\n- Warehouse: Berlin Distribution Center (DE-BER-01)\n- Reserved: 1 x B0C13M8GJZ, 1 x B0B232NZJL',
#  'references': [{'id': 'B0C13M8GJZ',
#    'description': 'Jesebang Wireless Earbud, Bluetooth Headphones 5.3 Stereo Earphones 2023 Ear Buds 30H ENC Mic, in-Ear Earbud USB-C LED Display IP7 Waterproof Sport Headset for Android iOS, Green'},
#   {'id': 'B0B232NZJL',
#    'description': '2022 Newest HP 14 Laptop, 14" HD IPS Display, AMD Ryzen 3 3250U Processor, AMD Radeon Graphics, 8GB RAM, 128GB SSD, USB Type-C, HDMI, Long Battery Life Up to 10 Hours, Windows 11 + Microfiber Cloth'},
#   {'id': 'B0C13M8GJZ',
#    'description': 'Review chunks for Jesebang Wireless Earbud'},
#   {'id': 'B0B232NZJL', 'description': 'Review chunks for HP 14 Laptop'}],
#  'user_id': 'failure-mode-discovery-01',
#  'cart_id': 'failure-mode-discovery-01'}

# %%
print(result_1["answer"])
# Out:
# I selected the best-reviewed items in each category, added them to your cart, and reserved them in the Berlin Distribution Center.
#
# Selected items:
# - Earphones: Jesebang Wireless Earbud (ID: B0C13M8GJZ, rating 4.9)
# - Laptop: HP 14 Laptop with AMD Ryzen 3 3250U, 8GB RAM, 128GB SSD (ID: B0B232NZJL, rating 4.4)
#
# Quick review summary:
# - Earphones positives: strong battery life, easy pairing/setup, comfortable fit, clear sound, useful LED battery display.
# - Earphones negatives: some reviews mention the low mid range can be too strong and that the build is not as sturdy as premium brands.
# - Laptop positives: fast for school/work/basic use, good battery life, easy setup, lightweight, good value.
# - Laptop negatives: several reviews mention no backlit keyboard, some mention shutdowns after inactivity, noisy ventilation, and concerns about misleading specs/S mode.
#
# Reservation:
# - Success: yes
# - Warehouse: Berlin Distribution Center (DE-BER-01)
# - Reserved: 1 x B0C13M8GJZ, 1 x B0B232NZJL

# %%
initial_state = {
    "messages": [HumanMessage(content="Can i get some earphones and a laptop? Could you also give me some positive and negative reviews about each suggestion?")],
    "user_id": "0000000000005003",
    "cart_id": "0000000000005003"
}
config = {
    "configurable": {
        "thread_id": "0000000000005003"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_2 = chunk[1]

# %%
initial_state = {
    "messages": [HumanMessage(content="Can you then add the best reviewed items from each category to my cart?")],
    "user_id": "0000000000005003",
    "cart_id": "0000000000005003",
    "coordinator_agent": {
        "iteration": 0,
        "final_answer": False,
        "plan": [],
        "next_agent": ""
    },
    "product_qna_agent": {
        "iteration": 0,
        "final_answer": False
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False
    },
    "warehouse_manager_agent": {
        "iteration": 0,
        "final_answer": False
    }
}
config = {
    "configurable": {
        "thread_id": "0000000000005003"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_2 = chunk[1]

# %%
initial_state = {
    "messages": [HumanMessage(content="Can i get some earphones and a laptop?")],
    "user_id": "failure-mode-discovery-02",
    "cart_id": "failure-mode-discovery-02"
}
config = {
    "configurable": {
        "thread_id": "failure-mode-discovery-02"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_2 = chunk[1]

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a green speaker for outdoors use?")],
    "user_id": "failure-mode-discovery-03",
    "cart_id": "failure-mode-discovery-03"
}
config = {
    "configurable": {
        "thread_id": "failure-mode-discovery-03"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_3 = chunk[1]
