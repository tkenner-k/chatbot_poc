# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env", override=True)
# Out:
# True

# %%
os.getenv("OPENAI_API_KEY")

# %% [markdown]
# #OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# orbit, velvet, cinnamon, lantern, eclipse, ripple, granite, fjord, sizzle, willow

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# Here are 10 random words:
#
# 1) comet
# 2) ember
# 3) velvet
# 4) quiver
# 5) lantern
# 6) willow
# 7) prism
# 8) falcon
# 9) ripple
# 10) scribe

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=149, prompt_tokens=24, total_tokens=173, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=128, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)
# Out:
# drift ember mosaic quantum willow zephyr lantern velvet citrus ripple

# %% [markdown]
# ### Google genai client [Currently not working]

# %%
# from google import genai

# gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# response = gemini_client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents=["You are a helpful assistant",
#               "can you print 15 random words?"]
# )

# print(response.text)

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"}
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Diamond
# 3. Computer
# 4. Butterfly
# 5. Football
# 6. Pineapple
# 7. Guitar
# 8. Snowflake
# 9. Perfume
# 10. Banana
# 11. Bicycle
# 12. Starfish
# 13. Caramel
# 14. Llama
# 15. Submarine
# 16. Coffee
# 17. Harmonica
# 18. Peacock
# 19. Fiddle
# 20. Waterfall

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY1"),

)

response = client.responses.create(
  model="gpt-5.4-mini",
  input="write a haiku about ai",
  store=True,
)

print(response.output_text);
# Out:
# Silent circuits hum
# Thoughts bloom in electric dawn
# Dreams learn how to speak
