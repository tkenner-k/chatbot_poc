# %%
from pydantic import BaseModel

import cohere

from langchain_openai import ChatOpenAI
from langchain_core.tools import tool

from langsmith import traceable, get_current_run_tree

import instructor

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send

from langchain_core.messages import SystemMessage, convert_to_openai_messages, HumanMessage, AIMessage
from IPython.display import Image, display

from typing import Literal, Dict, Any, Annotated, List
from pydantic import Field
from operator import add

import random
import openai
import pandas as pd

from jinja2 import Template

from qdrant_client import QdrantClient
from qdrant_client import models
from qdrant_client.models import Document, Prefetch, FusionQuery, FieldCondition, MatchAny, Filter

# %% [markdown]
# ### Agent Graph with Loopback from Tools (ReAct Agent)

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "text-embedding-3-small"
    }
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model
    )

    current_run = get_current_run_tree()
    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens,
        }

    return response.data[0].embedding

# %% [markdown]
# ### Items metadata retrieval tool

# %%
@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retrieve_data(query, qdrant_client, k=5, hybrid=True):

    query_embedding = get_embedding(query)

    if hybrid:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            prefetch=[
                Prefetch(
                    query=query_embedding,
                    using="text-embedding-3-small",
                    limit=20
                ),
                Prefetch(
                    query=Document(
                        text=query,
                        model="qdrant/bm25"
                    ),
                    using="bm25",
                    limit=20
                )
            ],
            query=models.RrfQuery(rrf=models.Rrf(weights=[3,1])),
            limit=k
        )
    else:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            query=query_embedding,
            using="text-embedding-3-small",
            limit=k
        )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["preprocessed_description"])
        similarity_scores.append(result.score)
        retrieved_context_ratings.append(result.payload["average_rating"])

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "similarity_scores": similarity_scores,
        "retrieved_context_ratings": retrieved_context_ratings
    }


@traceable(
    name="rerank_data",
    run_type="tool"
)
def rerank_data(query, context, top_k=5):

    cohere_client = cohere.ClientV2()

    response = cohere_client.rerank(
        model="rerank-v4.0-pro",
        query=query,
        documents=context["retrieved_context"],
        top_n=top_k
    )

    order = [result.index for result in response.results]

    return {
        "retrieved_context_ids": [context["retrieved_context_ids"][i] for i in order],
        "retrieved_context": [context["retrieved_context"][i] for i in order],
        "similarity_scores": [context["similarity_scores"][i] for i in order],
        "retrieved_context_ratings": [context["retrieved_context_ratings"][i] for i in order]
    }


@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


@tool
def get_formatted_item_context(query: str, top_k: int = 5) -> str:

    """Search available products and return the top k matching inventory items.

Expand the customer's question into 1-5 concise search statements and issue them
in parallel in a single turn. Each statement covers one distinct product or
attribute; no two may express the same intent. Use natural product-description
language. If no brand or model is specified, search broadly rather than refusing.

    "Earphones for me and a waterproof speaker"
        -> "Personal earphones" | "Waterproof speaker"
    "A warm winter jacket for hiking"
        -> "Insulated winter jacket" | "Hiking outerwear for cold weather"

Before calling, check what earlier calls in this conversation already returned.
Search only for what is missing; results already retrieved remain valid and must
not be fetched again.

Args:
    query: A single search statement describing one product or attribute.
    top_k: Number of items to retrieve. Works best with 5 or more.

Returns:
    A string of the top k available products, each prefixed with its ID and
    average rating.
    """

    qdrant_client = QdrantClient(url="http://localhost:6333")

    retrieved_context = retrieve_data(
        query,
        qdrant_client,
        k=20
    )

    retrieved_context = rerank_data(query, retrieved_context, top_k=top_k)
    formatted_context = process_context(retrieved_context)

    return formatted_context

# %% [markdown]
# ### Reviews retrieval tool

# %%
@traceable(
    name="retrieve_prefiltered_reviews_data",
    run_type="retriever"
)
def retrieve_prefiltered_reviews_data(query, parent_asins, qdrant_client, k=5):

    query_embedding = get_embedding(query)

    results = qdrant_client.query_points(
        collection_name="Amazon-reviews-collection-01",
        prefetch=[
            Prefetch(
                query=query_embedding,
                using="text-embedding-3-small",
                filter=Filter(
                    must=[
                        FieldCondition(
                            key="parent_asin",
                            match=MatchAny(
                                any=parent_asins
                            )
                        )
                    ]
                ),
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k
    )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["preprocessed_data"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "similarity_scores": similarity_scores,
    }

@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_reviews_context(context):

    formatted_context = ""

    for id, chunk in zip(context["retrieved_context_ids"], context["retrieved_context"]):
        formatted_context += f"- ID: {id}, user review: {chunk}\n"

    return formatted_context

@tool
def get_formatted_reviews_context(query: str, parent_asins: list[str], top_k: int = 5) -> str:

    """Get the top k reviews matching a query for a list of prefiltered items.
    
    Args:
        query: The query to get the top k reviews for
        item_list: The list of item IDs to prefilter for before running the query
        top_k: The number of reviews to retrieve, this should be at least 20 if multipple items are prefiltered
    
    Returns:
        A string of the top k context chunks with IDs prepending each chunk, each representing a review for a given inventory item for a given query.
    """

    qdrant_client = QdrantClient(url="http://localhost:6333")

    retrieved_context = retrieve_prefiltered_reviews_data(
        query,
        parent_asins,
        qdrant_client,
        top_k
    )
    formatted_context = process_reviews_context(retrieved_context)

    return formatted_context

# %% [markdown]
# ### State and Pydantic Models for Structured Outputs

# %%
class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question")
    description: str = Field(description="Description of the item used to answer the question")

class FinalResponse(BaseModel):

    """Call this tool when the final answer is possible using available context."""

    answer: str = Field(description="Answer to the question")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question")

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    question_relevant: bool = False
    iteration: int = 0
    answer: str = ""
    final_answer: bool = False
    references: list[RAGUsedContext] = []

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def agent_node(state: State) -> dict:
    
    prompt_template = """You are a shopping assistant answering customer questions about products in stock.

## Procedure

Before every tool call, check what previous tool calls in this conversation already
returned. Search only for what's genuinely missing. If nothing is missing, call
FinalResponse instead — previously retrieved data is as valid as fresh data, and
re-running a search you already ran is an error.

Customer: "Which of those speakers is cheapest?"
→ Speakers and prices already retrieved. No search. FinalResponse.

Customer: "Does that jacket come with a rain shell, and do you have gloves?"
→ Jacket specs already retrieved; gloves are not. Search gloves only.

## Answering

- Never state a product detail that isn't in the retrieved data.
- Describe products with specifications in bullet points.
- In references, include every chunk that contributed to your answer with the chunk id and product name.
- Call retrieved data "available products", never "context".
- Nothing relevant returned → say so, ask the customer to refine.
- Off-topic question → ask what product they're interested in.
"""

    template = Template(prompt_template)

    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [get_formatted_item_context, get_formatted_reviews_context, FinalResponse],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *state.messages
        ]
    )

    final_answer = False
    answer = ""
    references = []

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")
                references.extend(tool_call.get("args").get("references"))

                response = sanitise_response(response)

    return {
        "messages": [response],
        "final_answer": final_answer,
        "iteration": state.iteration + 1,
        "answer": answer,
        "references": references
    }

# %%
def tool_router(state: State) -> str:

    if state.final_answer:
        return "end"
    elif state.iteration > 2:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# ### User Intent Router Node

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str = Field(description="An answer to the question if the users question is not relevant to the products.")

# %%
@traceable(
    name="route_intent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def intent_router_node(state: State) -> dict:

    prompt_template = """You are a relevance router for a shopping assistant that answers questions about products in stock.

## Instructions

- Determine whether the question is about products, inventory, or purchasing.
- Questions about product features, availability, pricing, comparisons, and recommendations are relevant.
- Questions about store policies, personal advice, or unrelated topics are not relevant.

## Examples

Question: "Do you have running shoes under $100?"
Relevant: yes

Question: "What's the weather like today?"
Relevant: no - not related to products

Question: "Can you help me write an essay?"
Relevant: no - not related to products

Question: "Which laptop has the best battery life?"
Relevant: yes

Question: "What's your return policy?"
Relevant: no - about store policy, not product information
"""

    template = Template(prompt_template)

    prompt = template.render()

    messages = state.messages

    conversation = []

    conversation.append(convert_to_openai_messages(messages[-1]))

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt},
            *conversation
        ],
        reasoning={"effort": "none"},
        response_model=IntentRouterResponse
    )

    return {
        "question_relevant": response.question_relevant,
        "answer": response.answer
    }

# %%
def intent_router_conditional_edges(state: State) -> str:

    if state.question_relevant:
        return "agent_node"
    else:
        return "end"

# %% [markdown]
# ### Graph Construction

# %%
workflow = StateGraph(State)

tools = [get_formatted_item_context, get_formatted_reviews_context]
tool_node = ToolNode(tools)

workflow.add_node("tool_node", tool_node)
workflow.add_node("agent_node", agent_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "agent_node": "agent_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "agent_node",
    tool_router,
    {
        "tools": "tool_node",
        "end": END
    }
)

workflow.add_edge("tool_node", "agent_node")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?")]
}

# %%
result = graph.invoke(initial_state)

# %%
result
# Out:
# {'messages': [HumanMessage(content='Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content=[{'id': 'rs_0707585c0df924f2006a66787e87ec819a8540c99b6c4b5cd6', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqZnh_gQ8mBLZlVUYOORHSl9HfgnXsfYDcCe53E2Cy08qVbvci_y3ibj2onNzPR6DEDnKP9FVooREHPgHVlkpcFov7cO_V2FEr3ucSlexqS9HZ3Vw7ndLvp0sW13nd-JYb7saPOHOAsEVlORBW5eNS85htiAT2WoidNXbyHJndz4_KNC1q0drZvMH5yj1RiuAA-OnU537Bky86ChoTwX75dJQEnZwCgY8tnGwSAJfUF_qPBQDLc1pQtNojPr8jNkJI9vgrpr1vXDdTyIz8BkXMaZ_hyupZAE-LORIwqQ0AFjeJ0jn8dHanRn7b9SsPcg1CgP6FUC5B1k6jZyJaiV72UpEEOVWRGst-8d7wRBEMVIr1xnDKZAIAD5qLwdpj_PwlWvKlNLVbbcmny89z0bvOmF-RagCeipJGzSgqr_CtLEy9U7DvdFE3PSWlMVfYf8NpjDNyJxcEZNYu74Dx9NlWTE2kRs52YD6wO-jJ6avG2iZlNNXGXSFczCN7TOTd5CWXsFx-Qb9tc2cWu0eKE8483JhNOIanLIIJrhvxnAlTpAYuLXGpzWzRxxq5a-0KdNgn-1ldQbgLoPgsySnAJs6NJcxmrXltA7ESQLQUhXYF7js04UVGXExPfPK35bQYK1sbyisppuMgOEFRDhZdxrLsrHb
providing a comprehensive health management solution. Invest in your health today! ⌚【Unleash Your Athletic Potential】Smart watch for men android comes with 20 sport modes. Including walking, running, cycling and more. Enjoy your favorite tunes while exercising, and use the watch to track your progress and set new records. Make fitness fun and stay motivated with our smart watch. ⌚【Practical Features That Matter】Get more than just a watch with our multifunctional device. Set the time, receive notifications for calls and messages, control your music, check the weather, find your phone or watch, use the stopwatch, timer, alarm, game, receipt code, social code, calculator, NFC door card, and much more. Never miss a beat with our versatile and practical smart watch. ⌚【Larger Display, Better Experience】iOS Android smart watch Immerse yourself in the 1.8-inch super large color high-definition display, featuring amazing quality and expansive visuals. Choose from over 200 custom watch faces or upload your own photos to create a personalized look. Stand out from the crowd and enjoy a better interactive experience with our smart watch.\n- ID: B09WLQFBXZ, rating: 3.6, description: GMYOOD Smart Watch for Women, 2022 Smart Watch for Android Phones & iPhone Compatible, IP67 Waterproof Stainless Steel Activity Tracker with Blood Pressure Heart Rate SpO2 Sleep Tracker (Gold) ⌚【Your Watch, Your Style】1.08 inch full touch high definition IPS color screen, resolution 220 * 128, covered with a metal frame, so elegant and nice, but sturdy and anti-scratch. The smart watch contains 5 dials readily available to choose from along with another 30 more dials within the app. You can also customize your watch faces. It can be any photo, such as your family, pet ,etc. ☀【Your Personal Smart Assistant】Activity tracker (pedometer, calories, distance), heart rate, various sport modes, sleep monitoring.,etc. Get notifications of Call, SMS, and APP messages(THE WATCH CAN NOT MAKE MESSAGES, CALLS or TEXT BACK, Bluetooth distance 8-10 meters), remote control of music and cameras, weather report, sedentary reminder, alarm clock, stopwatch, find phone, call rejection, brightness adjustment, power-saving mode, and other functions to meet your daily needs. 🏃【Stay Connected to Your Phone】 Connect fitness tracker with your phone, you will never miss a call and message. The gents fitness watch will vibrate to alert you if your phone receives a phone call, SMS text and SNS messages. SNS alert: Facebook, Wechat, Whatsapp, Skype, Line, Instagram, Twitter, ect. 💟【24 Hours Health Monitoring】 GMYOOD womens activity tracker has heart rate, blood pressure, blood oxygen monitor functions, female body care cycle, always pay attention to your physical health, but the data is just used for reference. This stainless steel smart wristwatch can also measure your sleep automatically, which helps you know awake, light, and deep sleep data. and provide a comprehensive sleep quality analysis  ...
#   ToolMessage(content='- ID: B0C9ZWCZ99, rating: 4.3, description: HP 15.6" HD Busienss Laptop Newest, 6-core AMD Ryzen 5 5500U(up to 4.0GHz), 8GB RAM, 256GB SSD, USB-A&C, WiFi, Fast Charge, Windows 11 + GM Accessory 【15.6" HD micro-edge Display】Revolutionize your display and see more of what you love with this slim bezel design that maximizes your viewing area foor an immersive multimedia experience. 【AMD Ryzen 5 5500U Mobile Processor】Create. Play. Work. Educate. Entertain. The possibilities are infinite. Be anywhere, go anywhere. Powers ultrathin notebooks that offer supreme performance, astonishing battery life, and modern features you need on-the-go. 【Upgraded to 8GB system memory for advanced multitasking】Substantial high-bandwidth RAM to smoothly run your games and photo and video-editing applications, as well as multiple programs and browser tabs all at once. 【Upgraded to 256GB SSD Storage】Boot up in seconds, get to files faster, and have room for loads of files with the lightning-quick solid state drive. 【Windows 11 Home】Windows 11 is the place to think, express, and create in a natural way. 2 x USB-A; 1 x USB-C; 1XHDMI.\n- ID: B0C18D24G9, rating: 4.1, description: ECOHERO 2023 Laptop, 14" 1920x1080 FHD IPS Screen, 12GB DDR4 RAM/256GB NVMe SSD, Intel N5095 Quad Core, Windows 11 laptops Computers, 2.4G/5G WiFi, Bluetooth 4.2, Support Type c PD3.0 Fast Charging 【Processor】11th Gen Intel Celeron Processor N5095 Quad-Core Quad-Threads 2.0GHz Processor (4M Cache, up to 2.90 GHz), Intel UHD Graphics, 10 nm Technology, TDP: 15 W. 【Memory & Storage】Built-in 12GB DDR4 high-frequency memory, fast response, helps to release better performance, multiple applications run at the same time without freezing, 256GB NVMe high-speed SSD, compared with ordinary SATA SSD, the read and write speed is increased by 5 times, up to 2000MB/S above. 【Screen】14" FHD IPS screen (1920 x 1080) Display, the picture is detailed and realistic, rich in color, presenting a clear and colorful world. 【Ports】 1 x USB 3.2 Gen 1, 2 x USB2.0, 1 x Full-featured Type-C (Support PD3.0 fast charge), 1 x Headphone Jack, 1 x Micro SD ( Supports up to 256GB ), 1 x DC, 1 x HD (Support HD output HD video), Built-in 2.4G and 5G dual-band WIFI, Bluetooth 4.2, Dual stereo speakers and Dual array microphone. 【System】The laptop comes with the latest version of windows 11 Pro pre-installed to help improve your productivity.\n- ID: B0B9JGHGDW, rating: 4.2, description: ASUS ZenBook 14X OLED Laptop, 14” WQXGA+ 16:10 Touch Display, Intel Core i7-1165G7 CPU, NVIDIA GeForce MX450, 16GB RAM, 512GB SSD, Windows 11 Pro, Pine Grey, UX5400EG-XB73T Aspect Ratio:16:10 Complimentary 3-month Adobe Creative Cloud subscription with the purchase. Learn more on ASUS website for more details Innovative ScreenPad: 5.65-inch interactive touchscreen trackpad that adapts to your needs for smarter control and multitasking 14” WQXGA+ (2880 x 1800) 16:10 OLED Touch Screen 400 nits display with ultra-slim 4-sided NanoEdge bezels Latest 11th generation Intel Core i7-1165G7 Quad Core Processor (12M Cache) Discrete NVIDIA GeForce MX450 graphics Fast storage and memory featuring 512GB PCIe NVMe M.2 SSD and 16GB LPDDR4X RAM, with Windows 11 Pro Pantone Validated, DCI-P3: 100% Glossy display with 92% screen-to-body ratio Extensive connectivity with Thunderbolt 4 via USB-C, USB 3.2 Type A, HDMI, 3.5mm Combo Audio Jack, Micro SD card reader, Wi-Fi 6 (802.11ax), and Bluetooth 5.0 Sleek and lightweight aluminum body at only 3.09 lbs and 0.67 inches thick, that is built to the MIL-STD 810H military standard for reliability and durability. Sleeve and USB-A to RJ45 gigabit ethernet adapter included.Ergonomic chiclet backlit keyboard with fingerprint sensor activated via Windows Hello\n- ID: B09J52P1TD, rating: 4.4, description: HP 17.3" Flagship HD+ Business Laptop, Intel Quad Core i3-1125G4(Beat i5-1035G4), 8GB RAM, 256GB PCIe SSD, Bluetooth, HDMI, Webcam, Windows 11, Silver, w/GM Accessories 【11th Gen Intel Core ...
#   AIMessage(content='Here are suitable available products for each request:\n\n- Tablet for your kid:\n  - B0C7DCS2KW — KYASTER Kids Tablet, 7 inch, Android 12, 2GB RAM, 32GB ROM, parental controls, EVA kids-proof case\n  - B0BGHBL86V — Moonka Kids Tablet, 7 inch, Android 10, 1GB RAM, 32GB ROM, expandable storage, silicone case, parental control\n\n- Watch for you:\n  - B0B0YRXT52V — Smart Watch for Men Women, 1.8" display, call answering, Alexa built-in, IP68 waterproof, health tracking\n  - B0CFLR6R3X — SOUYIE Smart Watch, 1.8" HD display, Bluetooth calling, IP67 waterproof, heart rate/blood pressure/temperature monitoring\n\n- Laptop for your wife:\n  - B0B9JGHGDW — ASUS ZenBook 14X OLED, 14" touch display, Intel Core i7, 16GB RAM, 512GB SSD, Windows 11 Pro\n  - B0C9ZWCZ99 — HP 15.6" Business Laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11\n\n- Waterproof speaker:\n  - B0C996WY16 — Raymate Bluetooth Speaker, 30W, IPX7 waterproof, 1000 mins playtime\n  - B0BRB22GL4 — MIFA Portable Waterproof Bluetooth Speaker, IP67 waterproof/dustproof, 20W, 38 hrs playtime\n\nIf you want, I can narrow these down by budget, age, or preferred features.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'question_relevant': True,
#  'iteration': 2,
#  'answer': 'Here are suitable available products for each request:\n\n- Tablet for your kid:\n  - B0C7DCS2KW — KYASTER Kids Tablet, 7 inch, Android 12, 2GB RAM, 32GB ROM, parental controls, EVA kids-proof case\n  - B0BGHBL86V — Moonka Kids Tablet, 7 inch, Android 10, 1GB RAM, 32GB ROM, expandable storage, silicone case, parental control\n\n- Watch for you:\n  - B0B0YRXT52V — Smart Watch for Men Women, 1.8" display, call answering, Alexa built-in, IP68 waterproof, health tracking\n  - B0CFLR6R3X — SOUYIE Smart Watch, 1.8" HD display, Bluetooth calling, IP67 waterproof, heart rate/blood pressure/temperature monitoring\n\n- Laptop for your wife:\n  - B0B9JGHGDW — ASUS ZenBook 14X OLED, 14" touch display, Intel Core i7, 16GB RAM, 512GB SSD, Windows 11 Pro\n  - B0C9ZWCZ99 — HP 15.6" Business Laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11\n\n- Waterproof speaker:\n  - B0C996WY16 — Raymate Bluetooth Speaker, 30W, IPX7 waterproof, 1000 mins playtime\n  - B0BRB22GL4 — MIFA Portable Waterproof Bluetooth Speaker, IP67 waterproof/dustproof, 20W, 38 hrs playtime\n\nIf you want, I can narrow these down by budget, age, or preferred features.',
#  'final_answer': True,
#  'references': [{'id': 'B0C7DCS2KW',
#    'description': 'KYASTER Kids Tablet, 7 inch 5G WiFi 6 Android 12 Tablet for Kids, Full HD 1920x1200 IPS Screen, 2GB RAM 32GB ROM, Parental Controls, EVA Kids-Proof Case with Stylus'},
#   {'id': 'B0BGHBL86V',
#    'description': 'Moonka Kids Tablet 7 inch Android 10 kids learning tablet, 1GB RAM 32GB ROM, expandable storage, silicone case, parental control'},
#   {'id': 'B0B0YRXT52V',
#    'description': 'Smart Watch for Men Women, 1.8" waterproof fitness tracker with Alexa, call answering, heart rate and SpO2 monitoring'},
#   {'id': 'B0CFLR6R3X',
#    'description': 'SOUYIE Smart Watch for Men Women, Bluetooth calling, 1.8 inch HD display, IP67 waterproof fitness tracker'},
#   {'id': 'B0B9JGHGDW',
#    'description': 'ASUS ZenBook 14X OLED Laptop, 14" touch display, Intel Core i7-1165G7, 16GB RAM, 512GB SSD, Windows 11 Pro'},
#   {'id': 'B0C9ZWCZ99',
#    'description': 'HP 15.6" HD Business Laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11'},
#   {'id': 'B0C996WY16',
#    'description': 'Raymate Bluetooth Speakers, 30W IPX7 waterproof speaker with DSP and 1000 mins playtime'},
#   {'id': 'B0BRB22GL4',
#    'description': 'MIFA Portable Waterproof Bluetooth Speaker, IP67 waterproof and dustproof, 20W, 38 hours playtime'}]}

# %%
print(result["answer"])
# Out:
# Here are suitable available products for each request:
#
# - Tablet for your kid:
#   - B0C7DCS2KW — KYASTER Kids Tablet, 7 inch, Android 12, 2GB RAM, 32GB ROM, parental controls, EVA kids-proof case
#   - B0BGHBL86V — Moonka Kids Tablet, 7 inch, Android 10, 1GB RAM, 32GB ROM, expandable storage, silicone case, parental control
#
# - Watch for you:
#   - B0B0YRXT52V — Smart Watch for Men Women, 1.8" display, call answering, Alexa built-in, IP68 waterproof, health tracking
#   - B0CFLR6R3X — SOUYIE Smart Watch, 1.8" HD display, Bluetooth calling, IP67 waterproof, heart rate/blood pressure/temperature monitoring
#
# - Laptop for your wife:
#   - B0B9JGHGDW — ASUS ZenBook 14X OLED, 14" touch display, Intel Core i7, 16GB RAM, 512GB SSD, Windows 11 Pro
#   - B0C9ZWCZ99 — HP 15.6" Business Laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11
#
# - Waterproof speaker:
#   - B0C996WY16 — Raymate Bluetooth Speaker, 30W, IPX7 waterproof, 1000 mins playtime
#   - B0BRB22GL4 — MIFA Portable Waterproof Bluetooth Speaker, IP67 waterproof/dustproof, 20W, 38 hrs playtime
#
# If you want, I can narrow these down by budget, age, or preferred features.

# %% [markdown]
# ### State Streaming

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# Multiturn Conversation

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000000100"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates"]
    ):
        print(chunk)
# Out:
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': ''}})
# ('updates', {'agent_node': {'messages': [AIMessage(content='Here are some available products that match your request:\n\n- Tablet for your kid\n  - B0B3R74TZC: 7-inch kids tablet, Android 10, 1GB RAM + 32GB ROM, parental controls, kid-friendly apps preinstalled.\n  - B0BGHBL86V: 7-inch kids tablet, Android 10, 1GB RAM + 32GB ROM, parental controls, expandable storage.\n  - B0C7DCS2KW: 7-inch kids tablet, Android 12 Go, 2GB RAM + 32GB ROM, Full HD display, parental controls.\n\n- Watch for you\n  - B0CFLR6R3X: Smart watch with Bluetooth calling, 1.8-inch HD display, blood pressure/heart rate/sleep monitoring, IP67 waterproof.\n  - B09QKT279R: Smart watch with call support, waterproof design, heart rate and blood pressure monitoring.\n  - B0C7CTNS12: Smart watch with call receive/dial, 1.32-inch HD touch screen, waterproof, heart rate/sleep/blood oxygen tracking.\n\n- Laptop for your wife\n  - B0C9ZWCZ99: HP 15.6-inch business laptop, AMD Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 
iuJ9uaXNWmw8HDe54dYKLu4-dzEpripC9Jpv-HsnJ5LXVq5_OfiQWrfMfoOltN5YHU1JKaeqPsar0QOj-sfOOzzjYGUQV9X5x4KLL6iGxMgCgrE9qeHUqzQm1fZMMpmQ5cNdg708y8gfZMGkQuUjDl2kXYFxakIlkTtXlqr7fF0RFdg=='}, {'arguments': '{"query":"Kids tablet", "top_k":5}', 'call_id': 'call_fOLtGYD67T2z5KoGdXWsFZdo', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a66768639fc819b9156339346c52fae', 'status': 'completed'}, {'arguments': '{"query":"Smartwatch for adults", "top_k":5}', 'call_id': 'call_QXjQ64tSykwKDz2JixwiWVne', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a6676863a0c819ba4e65bf180c73e5a', 'status': 'completed'}, {'arguments': '{"query":"Laptop for general use", "top_k":5}', 'call_id': 'call_AKfFJ7vmvA79N74jaIVGhVS1', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a6676863a14819ba1b2d738a255a67a', 'status': 'completed'}, {'arguments': '{"query":"Waterproof speaker", "top_k":5}', 'call_id': 'call_7amzt3eb2HTdncMraBiaZ7Jh', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a6676863a1c819bb0c9f06458a8b128', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0625677783b03897006a6676852608819b9f097367f4f948d8', 'created_at': 1785099909.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_0625677783b03897006a6676852608819b9f097367f4f948d8', tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'Kids tablet', 'top_k': 5}, 'id': 'call_fOLtGYD67T2z5KoGdXWsFZdo', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Smartwatch for adults', 'top_k': 5}, 'id': 'call_QXjQ64tSykwKDz2JixwiWVne', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Laptop for general use', 'top_k': 5}, 'id': 'call_AKfFJ7vmvA79N74jaIVGhVS1', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Waterproof speaker', 'top_k': 5}, 'id': 'call_7amzt3eb2HTdncMraBiaZ7Jh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 723, 'output_tokens': 140, 'total_tokens': 863, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 17}}), ToolMessage(content='- ID: B0B3R74TZC, rating: 3.7, description: Kids Tablet 7 inch WiFi Kids Tablets 32G Android 10 Tablet for Kids Dual Camera Educational Games Parental Control with Kids Software Pre-Inst ...
# ('updates', {'agent_node': {'messages': [AIMessage(content='Yes — here are available products for each of the four requests:\n\n- Tablet for your kid:\n  - B0B3R74TZC — 7" Kids Tablet, Android 10, parental controls, 32GB storage\n  - B0BGHBL86V — 7" Kids Tablet, Android 10, 32GB storage, expandable\n  - B0C7DCS2KW — 7" Kids Tablet, Android 12, 2GB RAM, 32GB storage, kids-proof case\n\n- Watch for you:\n  - B0CFLR6R3X — Smart watch with Bluetooth calling, health tracking, IP67 waterproof\n  - B09QKT279R — Smart watch with call answer/make, waterproof, health tracking\n  - B09KLYPYTN — Smart watch with IP68 waterproofing, health tracking\n  - B0C7CTNS12 — Smart watch with call receive/dial, waterproof, health tracking\n  - B09SNWJC5N — Smartwatch with IP68 waterproofing, heart rate, sleep, SpO2 tracking\n\n- Laptop for your wife:\n  - B0C9ZWCZ99 — HP 15.6" laptop, Ryzen 5, 8GB RAM, 256GB SSD, Windows 11\n  - B09J52P1TD — HP 17.3" laptop, Intel i3, 8GB RAM, 256GB SSD, Windows 11\n  - B09XJJNCXZ — HP 14" touchscreen laptop, Intel i3, 8GB RAM, 128GB SSD\n  - B0B232NZJL — HP 14" laptop, Ryzen 3, 8GB RAM, 128GB SSD, Windows 11\n  - B0B9XSS7DC — 11.6" 2-in-1 laptop, Celeron N4000, 4GB RAM, 128GB storage\n\n- Waterproof speaker:\n  - B0C996WY16 — 30W IPX7 waterproof Bluetooth speaker, 1000+ minutes playtime\n  - B0CB3CLQYS — IPX7 waterproof Bluetooth speaker, 20W, 18H playtime\n  - B09SNYHYV7 — IPX6 waterproof 60W Bluetooth speaker with subwoofer\n  - B0BRB22GL4 — IP67 waterproof outdoor Bluetooth speaker, 38H playtime\n  - B09S3GRY4Q — Waterproof shower Bluetooth speaker with clip and suction cup', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'final_answer': True, 'iteration': 3, 'answer': 'Yes — here are available products for each of the four requests:\n\n- Tablet for your kid:\n  - B0B3R74TZC — 7" Kids Tablet, Android 10, parental controls, 32GB storage\n  - B0BGHBL86V — 7" Kids Tablet, Android 10, 32GB storage, expandable\n  - B0C7DCS2KW — 7" Kids Tablet, Android 12, 2GB RAM, 32GB storage, kids-proof case\n\n- Watch for you:\n  - B0CFLR6R3X — Smart watch with Bluetooth calling, health tracking, IP67 waterproof\n  - B09QKT279R — Smart watch with call answer/make, waterproof, health tracking\n  - B09KLYPYTN — Smart watch with IP68 waterproofing, health tracking\n  - B0C7CTNS12 — Smart watch with call receive/dial, waterproof, health tracking\n  - B09SNWJC5N — Smartwatch with IP68 waterproofing, heart rate, sleep, SpO2 tracking\n\n- Laptop for your wife:\n  - B0C9ZWCZ99 — HP 15.6" laptop, Ryzen 5, 8GB RAM, 256GB SSD, Windows 11\n  - B09J52P1TD — HP 17.3" laptop, Intel i3, 8GB RAM, 256GB SSD, Windows 11\n  - B09XJJNCXZ — HP 14" touchscreen laptop, Intel i3, 8GB RAM, 128GB SSD\n  - B0B232NZJL — HP 14" laptop, Ryzen 3, 8GB RAM, 128GB SSD, Windows 11\n  - B0B9XSS7DC — 11.6" 2-in-1 laptop, Celeron N4000, 4GB RAM, 128GB storage\n\n- Waterproof speaker:\n  - B0C996WY16 — 30W IPX7 waterproof Bluetooth speaker, 1000+ minutes playtime\n  - B0CB3CLQYS — IPX7 waterproof Bluetooth speaker, 20W, 18H playtime\n  - B09SNYHYV7 — IPX6 waterproof 60W Bluetooth speaker with subwoofer\n  - B0BRB22GL4 — IP67 waterproof outdoor Bluetooth speaker, 38H playtime\n  - B09S3GRY4Q — Waterproof shower Bluetooth speaker with clip and suction cup', 'references': [{'id': 'B0B3R74TZC', 'description': 'Kids Tablet 7 inch WiFi Kids Tablets 32G Android 10 Tablet for Kids Dual Camera Educational Games Parental Control with Kids Software Pre-Installed'}, {'id': 'B0BGHBL86V', 'description': 'Kids Tablet 7 inch Android Toddler Tablet for Kids Learning APP Preinstalled 1GB RAM+32GB ROM 256GB Expand Support, 2MP Rear Camera'}, {'id': 'B0C7DCS2KW', 'description': 'KYASTER Kids Tablet, 7 inch 5G WiFi 6 Android 12 Tablet for Kids, Full HD 1920x1200 IPS Screen, 2GB RAM 32GB ROM'}, {'id': 'B0CFLR6R3X', 'description': 'SOUYIE Smart Watch for Men Women, with Bluetooth Calling, 1.8 Inch HD Display, IP67 Waterproof Fitness Tracker'}, {'id': 'B09Q ...
# ('debug', {'step': 8, 'timestamp': '2026-07-26T21:14:02.520433+00:00', 'type': 'task_result', 'payload': {'id': 'd0144650-1199-4872-f2ef-cbf79c7be9e7', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='Yes — here are available products for each of the four requests:\n\n- Tablet for your kid:\n  - B0B3R74TZC — 7" Kids Tablet, Android 10, parental controls, 32GB storage\n  - B0BGHBL86V — 7" Kids Tablet, Android 10, 32GB storage, expandable\n  - B0C7DCS2KW — 7" Kids Tablet, Android 12, 2GB RAM, 32GB storage, kids-proof case\n\n- Watch for you:\n  - B0CFLR6R3X — Smart watch with Bluetooth calling, health tracking, IP67 waterproof\n  - B09QKT279R — Smart watch with call answer/make, waterproof, health tracking\n  - B09KLYPYTN — Smart watch with IP68 waterproofing, health tracking\n  - B0C7CTNS12 — Smart watch with call receive/dial, waterproof, health tracking\n  - B09SNWJC5N — Smartwatch with IP68 waterproofing, heart rate, sleep, SpO2 tracking\n\n- Laptop for your wife:\n  - B0C9ZWCZ99 — HP 15.6" laptop, Ryzen 5, 8GB RAM, 256GB SSD, Windows 11\n  - B09J52P1TD — HP 17.3" laptop, Intel i3, 8GB RAM, 256GB SSD, Windows 11\n  - B09XJJNCXZ — HP 14" touchscreen laptop, Intel i3, 8GB RAM, 128GB SSD\n  - B0B232NZJL — HP 14" laptop, Ryzen 3, 8GB RAM, 128GB SSD, Windows 11\n  - B0B9XSS7DC — 11.6" 2-in-1 laptop, Celeron N4000, 4GB RAM, 128GB storage\n\n- Waterproof speaker:\n  - B0C996WY16 — 30W IPX7 waterproof Bluetooth speaker, 1000+ minutes playtime\n  - B0CB3CLQYS — IPX7 waterproof Bluetooth speaker, 20W, 18H playtime\n  - B09SNYHYV7 — IPX6 waterproof 60W Bluetooth speaker with subwoofer\n  - B0BRB22GL4 — IP67 waterproof outdoor Bluetooth speaker, 38H playtime\n  - B09S3GRY4Q — Waterproof shower Bluetooth speaker with clip and suction cup', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'final_answer': True, 'iteration': 3, 'answer': 'Yes — here are available products for each of the four requests:\n\n- Tablet for your kid:\n  - B0B3R74TZC — 7" Kids Tablet, Android 10, parental controls, 32GB storage\n  - B0BGHBL86V — 7" Kids Tablet, Android 10, 32GB storage, expandable\n  - B0C7DCS2KW — 7" Kids Tablet, Android 12, 2GB RAM, 32GB storage, kids-proof case\n\n- Watch for you:\n  - B0CFLR6R3X — Smart watch with Bluetooth calling, health tracking, IP67 waterproof\n  - B09QKT279R — Smart watch with call answer/make, waterproof, health tracking\n  - B09KLYPYTN — Smart watch with IP68 waterproofing, health tracking\n  - B0C7CTNS12 — Smart watch with call receive/dial, waterproof, health tracking\n  - B09SNWJC5N — Smartwatch with IP68 waterproofing, heart rate, sleep, SpO2 tracking\n\n- Laptop for your wife:\n  - B0C9ZWCZ99 — HP 15.6" laptop, Ryzen 5, 8GB RAM, 256GB SSD, Windows 11\n  - B09J52P1TD — HP 17.
OeCdXKFdgqiCjOdbz0Y9Oq7FsqmxXGfAnxuSRsOD5w_PrVpx9JL2AezOtlKZbb5aloIYfd1bMMFQtXQKVjoCwAiRkEnY-RWsdDX0FJDkAYVghmOESz5VLRTzxNbhxccdzquaIgew3_K4Z9Lr7vhZrT95mrXuVqDs4FK2gUn_PHGTBrWGYWMgulPAa6Bi3w0AgeMpWs_MJewEq0C7uYWu3KHI34f9dVJyrLosKOwAY_vz8-aqnoBZ5hrVw3TkOiuJ9uaXNWmw8HDe54dYKLu4-dzEpripC9Jpv-HsnJ5LXVq5_OfiQWrfMfoOltN5YHU1JKaeqPsar0QOj-sfOOzzjYGUQV9X5x4KLL6iGxMgCgrE9qeHUqzQm1fZMMpmQ5cNdg708y8gfZMGkQuUjDl2kXYFxakIlkTtXlqr7fF0RFdg=='}, {'arguments': '{"query":"Kids tablet", "top_k":5}', 'call_id': 'call_fOLtGYD67T2z5KoGdXWsFZdo', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a66768639fc819b9156339346c52fae', 'status': 'completed'}, {'arguments': '{"query":"Smartwatch for adults", "top_k":5}', 'call_id': 'call_QXjQ64tSykwKDz2JixwiWVne', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a6676863a0c819ba4e65bf180c73e5a', 'status': 'completed'}, {'arguments': '{"query":"Laptop for general use", "top_k":5}', 'call_id': 'call_AKfFJ7vmvA79N74jaIVGhVS1', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a6676863a14819ba1b2d738a255a67a', 'status': 'completed'}, {'arguments': '{"query":"Waterproof speaker", "top_k":5}', 'call_id': 'call_7amzt3eb2HTdncMraBiaZ7Jh', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0625677783b03897006a6676863a1c819bb0c9f06458a8b128', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0625677783b03897006a6676852608819b9f097367f4f948d8', 'created_at': 1785099909.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_0625677783b03897006a6676852608819b9f097367f4f948d8', tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'Kids tablet', 'top_k': 5}, 'id': 'call_fOLtGYD67T2z5KoGdXWsFZdo', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Smartwatch for adults', 'top_k': 5}, 'id': 'call_QXjQ64tSykwKDz2JixwiWVne', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Laptop for general use', 'top_k': 5}, 'id': 'call_AKfFJ7vmvA79N74jaIVGhVS1', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Waterproof speaker', 'top_k': 5}, 'id': 'call_7amzt3eb2HTdncMraBiaZ7Jh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 723, 'output_tokens': 140, 'total_tokens': 863, 'input_token_details': {'cache_read': 0}, 'output_token_details': {' ...

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000000102"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates", "tasks"]
    ):
        print(chunk)
# Out:
# ('tasks', {'id': '1cb8cd29-e4db-f28b-7842-f106d581373a', 'name': 'intent_router_node', 'input': State(messages=[HumanMessage(content='Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'id': 'rs_080bed0761b1aa07006a66769e43e88198b0debd3da40b79f7', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAAB
 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_080bed0761b1aa07006a66769f4cc081988e30257d61aaa9cb', 'status': 'completed'}, {'arguments': '{"query":"Laptop for home or office use", "top_k":5}', 'call_id': 'call_B9pyHFWQVM2irha3cJzrex8A', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_080bed0761b1aa07006a66769f4cc88198a3e6ff450c13f728', 'status': 'completed'}, {'arguments': '{"query":"Waterproof speaker", "top_k":5}', 'call_id': 'call_NJCpQRnRxgz4OKgir6ueQeMn', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_080bed0761b1aa07006a66769f4cd08198aebcd5a96f7a23c5', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_080bed0761b1aa07006a66769dd9248198b247f852ea79e86c', 'created_at': 1785099933.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_080bed0761b1aa07006a66769dd9248198b247f852ea79e86c', tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'Kid-friendly tablet', 'top_k': 5}, 'id': 'call_2klr9zKSh1eyhOu0xlVEslPG', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Smartwatch for everyday wear', 'top_k': 5}, 'id': 'call_f4QeRDbXbx7Px8WhwPAzFUOa', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Laptop for home or office use', 'top_k': 5}, 'id': 'call_B9pyHFWQVM2irha3cJzrex8A', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Waterproof speaker', 'top_k': 5}, 'id': 'call_NJCpQRnRxgz4OKgir6ueQeMn', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 723, 'output_tokens': 143, 'total_tokens': 866, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 16}}), ToolMessage(content='- ID: B0BGHBL86V, rating: 4.0, description: Kids Tablet 7 inch Android Toddler Tablet for Kids Learning APP Preinstalled 1GB RAM+32GB ROM 256GB Expand Support, 2MP Rear Camera Children’s Education Tablet Google Play YouTube Netflix ages 3 to 14 【Tablet M ...
# ('updates', {'agent_node': {'messages': [AIMessage(content='Here are available products for each item:\n\n- Tablet for your kid:\n  - B0C7DCS2KW: 7" kids tablet, Android 12 Go, 2GB RAM, 32GB storage, full HD 1920x1200 IPS screen, parental controls, kids-proof EVA case, stylus.\n  - B0BGHBL86V: 7" kids tablet, Android 10, 1GB RAM, 32GB storage, expandable via microSD, silicone case, parental controls.\n\n- Watch for you:\n  - B0BYRXT52V: 1.8" smart watch, Alexa built in, Bluetooth calling, heart rate/SpO2/sleep tracking, IP68 waterproof.\n  - B0CFLR6R3X: 1.8" smart watch, Bluetooth calling, blood pressure/heart rate/temperature/sleep monitoring, IP67 waterproof.\n\n- Laptop for your wife:\n  - B0B4BJ8YQ6: Lenovo Chromebook 3, 14" FHD touchscreen, MediaTek MT8183, 4GB RAM, 64GB eMMC + 256GB microSD, Chrome OS.\n  - B0C9ZWCZ99: HP 15.6" laptop, Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11.\n  - B09J52P1TD: HP 17.3" laptop, Intel Core i3-1125G4, 8GB RAM, 256GB SSD, Windows 11.\n\n- Waterproof speaker:\n  - B0CB3CLQYS: IPX7 waterproof portable Bluetooth speaker, 20W, 18H playtime, Bluetooth 5.1.\n  - B09SNYHYV7: IPX6 waterproof Bluetooth speaker, 60W, 24H playtime, handle, subwoofer.\n\nIf you want, I can narrow these down by budget, size, or best overall pick.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'final_answer': True, 'iteration': 3, 'answer': 'Here are available products for each item:\n\n- Tablet for your kid:\n  - B0C7DCS2KW: 7" kids tablet, Android 12 Go, 2GB RAM, 32GB storage, full HD 1920x1200 IPS screen, parental controls, kids-proof EVA case, stylus.\n  - B0BGHBL86V: 7" kids tablet, Android 10, 1GB RAM, 32GB storage, expandable via microSD, silicone case, parental controls.\n\n- Watch for you:\n  - B0BYRXT52V: 1.8" smart watch, Alexa built in, Bluetooth calling, heart rate/SpO2/sleep tracking, IP68 waterproof.\n  - B0CFLR6R3X: 1.8" smart watch, Bluetooth calling, blood pressure/heart rate/temperature/sleep monitoring, IP67 waterproof.\n\n- Laptop for your wife:\n  - B0B4BJ8YQ6: Lenovo Chromebook 3, 14" FHD touchscreen, MediaTek MT8183, 4GB RAM, 64GB eMMC + 256GB microSD, Chrome OS.\n  - B0C9ZWCZ99: HP 15.6" laptop, Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11.\n  - B09J52P1TD: HP 17.3" laptop, Intel Core i3-1125G4, 8GB RAM, 256GB SSD, Windows 11.\n\n- Waterproof speaker:\n  - B0CB3CLQYS: IPX7 waterproof portable Bluetooth speaker, 20W, 18H playtime, Bluetooth 5.1.\n  - B09SNYHYV7: IPX6 waterproof Bluetooth speaker, 60W, 24H playtime, handle, subwoofer.\n\nIf you want, I can narrow these down by budget, size, or best overall pick.', 'references': [{'id': 'B0C7DCS2KW', 'description': '7" kids tablet, Android 12 Go, 2GB RAM, 32GB storage, full HD 1920x1200 IPS screen, parental controls, kids-proof EVA case, stylus'}, {'id': 'B0BGHBL86V', 'description': '7" kids tablet, Android 10, 1GB RAM, 32GB storage, expandable via microSD, silicone case, parental controls'}, {'id': 'B0BYRXT52V', 'description': '1.8" smart watch, Alexa built in, Bluetooth calling, heart rate/SpO2/sleep tracking, IP68 waterproof'}, {'id': 'B0CFLR6R3X', 'description': '1.8" smart watch, Bluetooth calling, blood pressure/heart rate/temperature/sleep monitoring, IP67 waterproof'}, {'id': 'B0B4BJ8YQ6', 'description': 'Lenovo Chromebook 3, 14" FHD touchscreen, MediaTek MT8183, 4GB RAM, 64GB eMMC + 256GB microSD, Chrome OS'}, {'id': 'B0C9ZWCZ99', 'description': 'HP 15.6" laptop, Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11'}, {'id': 'B09J52P1TD', 'description': 'HP 17.3" laptop, Intel Core i3-1125G4, 8GB RAM, 256GB SSD, Windows 11'}, {'id': 'B0CB3CLQYS', 'description': 'IPX7 waterproof portable Bluetooth speaker, 20W, 18H playtime, Bluetooth 5.1'}, {'id': 'B09SNYHYV7', 'description': 'IPX6 waterproof Bluetooth speaker, 60W, 24H playtime, handle, subwoofer'}]}})
# ('tasks', {'id': 'de2c19e3-1649-ee86-d8f9-c25ec3050612', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='Here are available products for each item:\n\n- Tablet for your kid:\n  - B0C7DCS2KW: 7" kids tablet, Android 12 Go, 2GB RAM, 32GB storage, full HD 1920x1200 IPS screen, parental controls, kids-proof EVA case, stylus.\n  - B0BGHBL86V: 7" kids tablet, Android 10, 1GB RAM, 32GB storage, expandable via microSD, silicone case, parental controls.\n\n- Watch for you:\n  - B0BYRXT52V: 1.8" smart watch, Alexa built in, Bluetooth calling, heart rate/SpO2/sleep tracking, IP68 waterproof.\n  - B0CFLR6R3X: 1.8" smart watch, Bluetooth calling, blood pressure/heart rate/temperature/sleep monitoring, IP67 waterproof.\n\n- Laptop for your wife:\n  - B0B4BJ8YQ6: Lenovo Chromebook 3, 14" FHD touchscreen, MediaTek MT8183, 4GB RAM, 64GB eMMC + 256GB microSD, Chrome OS.\n  - B0C9ZWCZ99: HP 15.6" laptop, Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11.\n  - B09J52P1TD: HP 17.3" laptop, Intel Core i3-1125G4, 8GB RAM, 256GB SSD, Windows 11.\n\n- Waterproof speaker:\n  - B0CB3CLQYS: IPX7 waterproof portable Bluetooth speaker, 20W, 18H playtime, Bluetooth 5.1.\n  - B09SNYHYV7: IPX6 waterproof Bluetooth speaker, 60W, 24H playtime, handle, subwoofer.\n\nIf you want, I can narrow these down by budget, size, or best overall pick.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'final_answer': True, 'iteration': 3, 'answer': 'Here are available products for each item:\n\n- Tablet for your kid:\n  - B0C7DCS2KW: 7" kids tablet, Android 12 Go, 2GB RAM, 32GB storage, full HD 1920x1200 IPS screen, parental controls, kids-proof EVA case, stylus.\n  - B0BGHBL86V: 7" kids tablet, Android 10, 1GB RAM, 32GB storage, expandable via microSD, silicone case, parental controls.\n\n- Watch for you:\n  - B0BYRXT52V: 1.8" smart watch, Alexa built in, Bluetooth calling, heart rate/SpO2/sleep tracking, IP68 waterproof.\n  - B0CFLR6R3X: 1.8" smart watch, Bluetooth calling, blood pressure/heart rate/temperature/sleep monitoring, IP67 waterproof.\n\n- Laptop for your wife:\n  - B0B4BJ8YQ6: Lenovo Chromebook 3, 14" FHD touchscreen, MediaTek MT8183, 4GB RAM, 64GB eMMC + 256GB microSD, Chrome OS.\n  - B0C9ZWCZ99: HP 15.6" laptop, Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11.\n  - B09J52P1TD: HP 17.3" laptop, Intel Core i3-1125G4, 8GB RAM, 256GB SSD, Windows 11.\n\n- Waterproof speaker:\n  - B0CB3CLQYS: IPX7 waterproof portable Bluetooth speaker, 20W, 18H playtime, Bluetooth 5.1.\n  - B09SNYHYV7: IPX6 waterproof Bluetooth speaker, 60W, 24H playtime, handle, subwoofer.\n\nIf you want, I can narrow these down by budget, size, or best overall pick.', 'references': [{'id': 'B0C7DCS2KW', 'description': '7" kids tablet, Android 12 Go, 2GB RAM, 32GB storage, full HD 1920x1200 IPS screen, parental controls, kids-proof EVA case, stylus'}, {'id': 'B0BGHBL86V', 'description': '7" kids tablet, Android 10, 1GB RAM, 32GB storage, expandable via microSD, silicone case, parental controls'}, {'id': 'B0BYRXT52V', 'description': '1.8" smart watch, Alexa built in, Bluetooth calling, heart rate/SpO2/sleep tracking, IP68 waterproof'}, {'id': 'B0CFLR6R3X', 'description': '1.8" smart watch, Bluetooth calling, blood pressure/heart rate/temperature/sleep monitoring, IP67 waterproof'}, {'id': 'B0B4BJ8YQ6', 'description': 'Lenovo Chromebook 3, 14" FHD touchscreen, MediaTek MT8183, 4GB RAM, 64GB eMMC + 256GB microSD, Chrome OS'}, {'id': 'B0C9ZWCZ99', 'description': 'HP 15.6" laptop, Ryzen 5 5500U, 8GB RAM, 256GB SSD, Windows 11'}, {'id': 'B09J52P1TD', 'description': 'HP 17.3" laptop, Intel Core i3-1125G4, 8GB RAM, 256GB SSD, Windows 11'}, {'id': 'B0CB3CLQYS', 'description': 'IPX7 waterproof portable Bluetooth speaker, 20W, 18H playtime, Bluetooth 5.1'}, {'id': 'B09SNYHYV7', 'description': 'IPX6 waterproof Bluetooth speaker, 60W, 24H playtime, handle, subwoofer'}]}, 'interrupts': []})

# %%
def process_graph_event(chunk):

    def _is_node_start(chunk):
        return chunk[1].get("type") == "task"

    def _tool_to_text(tool_call):
        if tool_call.get("name") == "get_formatted_item_context":
            return f"Looking for items: {tool_call.get('args').get('query', '')}."
        elif tool_call.get("name") == "get_formatted_reviews_context":
            return f"Fetching user reviews..."

    if _is_node_start(chunk):
        if chunk[1].get("payload", {}).get("name") == "intent_router_node":
            print("Analysing the question...")
        if chunk[1].get("payload", {}).get("name") == "agent_node":
            print("Planning...")
        if chunk[1].get("payload", {}).get("name") == "tool_node":
            message = " ".join([_tool_to_text(tool_call) for tool_call in chunk[1].get('payload', {}).get('input', {}).messages[-1].tool_calls])
            print(message)

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000000104"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates", "debug"]
    ):
        process_graph_event(chunk)
# Out:
# Analysing the question...
# Planning...

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker? Can you then fetch some positive and negative reviews for each suggestion?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000000109"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates", "debug"]
    ):
        process_graph_event(chunk)
# Out:
# Analysing the question...
# Planning...
# Looking for items: Kid-friendly tablet. Looking for items: Smartwatch for adult use. Looking for items: Laptop for work and home use. Looking for items: Waterproof speaker.
# Planning...
# Fetching user reviews... Fetching user reviews... Fetching user reviews... Fetching user reviews... Fetching user reviews... Fetching user reviews... Fetching user reviews... Fetching user reviews...
# Planning...

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker? Can you then fetch some positive and negative reviews for each suggestion?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000000109"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        print(chunk)
# Out:
# ('values', {'messages': [HumanMessage(content='Can I get a tablet for my kid, a watch for me, a laptop for my wife and a waterproof speaker? Can you then fetch some positive and negative reviews for each suggestion?', additional_kwargs={}, response_metadata={}), AIMessage(content=[{'id': 'rs_0c917b02d8bedab4006a6679855258819998ccac5c79c5aeb0', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqZnmG9dQJH5XiwRsrEag4e3NP0rCOtDmfl4s5WJ_0Hot6CNbCsW-rKINuG7MiH_O5NJ9wUChmohmqSdCDxXvP2CgemO2l-gybc8mQ91WAJ5vAZl5gzzZFEimDMqt8NlcalrTuyxKAEy7LEzfP_1CdCQ1pwRds3UsWtawzH0jEn4Uaqj1Drt2mdGTWe99MdrY8NBsR2uVNR8z4WbjIBwFqyha5uTjki6RlnRmLKIGeSkJW3eMOv40T1nfI-8PQF41yTrmk1I6cCORaDJwY
xgad9sewP_sRhXcjsUESX1o38d046L5-ShHj_bPQBq17nB4qDuHtxWx7YuLT7pBdtw-2EIEaVq3n3PB1uEXwzGABvZHVoaWBfWCd_IyuiQ5jlPTnAVRfvXYLk8KZOINeiwJnNe65z9Z4RIM7211-eMAwlR1hOwk0XF0hkXK3D46y-3xAY1flR2NSayqvJ6-zd9sz-lKEFqtC9i2sBKXB3UYgFQTu1LHz04_rpkR3KVEyWQtWtJ29BswCO_CwH3THdkfwtRLAWkSsIwLGlPrH_7vlIUNdIntqh1eUlXwwxP7Jj3g2tfJBe9cj8Xp1_Ak6iPjQHK2eko9xbWlVYBJK0vZgbExVX8g9LsP5omgjv4dkk4Gbs2Ka9xMa9FCeKUJqyK_oY1ps--ZGllE5DnypnXAvvHjCsLp7s2Lw6MbLBI6yOECRtTq23shjRDjllX1XbBEJj9icUYTdtC2unqKREeViF'}, {'arguments': '{"query":"Kid-friendly tablet", "top_k":5}', 'call_id': 'call_kIi462CJpn7p3SRUwRTiuqdN', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0c917b02d8bedab4006a66798623bc8199a00159d709939b5d', 'status': 'completed'}, {'arguments': '{"query":"Smartwatch for adult use", "top_k":5}', 'call_id': 'call_Na8AFZNWxwSK5hr7PtTMN7ge', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0c917b02d8bedab4006a66798623d08199a3109ea73b89a5ca', 'status': 'completed'}, {'arguments': '{"query":"Laptop for work and home use", "top_k":5}', 'call_id': 'call_t6sIQI6TLXAnMnsDbQqAe519', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0c917b02d8bedab4006a66798623d881999fe5c4079a41fd4f', 'status': 'completed'}, {'arguments': '{"query":"Waterproof speaker", "top_k":5}', 'call_id': 'call_NnLku7qkXuw47HBmLXe66ydV', 'name': 'get_formatted_item_context', 'type': 'function_call', 'id': 'fc_0c917b02d8bedab4006a66798623e08199a86a8de23ad90c2b', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0c917b02d8bedab4006a667984ef6c8199a7460073a59d9506', 'created_at': 1785100676.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_0c917b02d8bedab4006a667984ef6c8199a7460073a59d9506', tool_calls=[{'name': 'get_formatted_item_context', 'args': {'query': 'Kid-friendly tablet', 'top_k': 5}, 'id': 'call_kIi462CJpn7p3SRUwRTiuqdN', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Smartwatch for adult use', 'top_k': 5}, 'id': 'call_Na8AFZNWxwSK5hr7PtTMN7ge', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Laptop for work and home use', 'top_k': 5}, 'id': 'call_t6sIQI6TLXAnMnsDbQqAe519', 'type': 'tool_call'}, {'name': 'get_formatted_item_context', 'args': {'query': 'Waterproof speaker', 'top_k': 5}, 'id': 'call_NnLku7qkXuw47HBmLXe66ydV', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 736, 'output_tokens': 159, 'total_tokens': 895, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 32}}), ToolMessage(content='- ID: B0BGHBL86V, rating: 4.0, description: Kids Tablet 7 inch Android Toddler Tablet for Kids Learning APP Preinstalled 1GB RAM+32GB ROM 25 ...
